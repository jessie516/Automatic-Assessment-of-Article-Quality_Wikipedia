# %%
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Mounted at /content/drive

# %%
import pandas as pd
import numpy as np
import seaborn as sns
import matplotlib.pyplot as plt

# %%
df = pd.read_csv('/content/drive/MyDrive/학교/Dissertation/Features/all_features2.csv')
df.drop(['Unnamed: 0'], axis=1, inplace=True)
df
# Out:
#                                  title  page_id  char_count  word_count  \
# 0                      Mayan languages   182013       37370        6527
# 1                           Mu'awiya I   207068       67665       12267
# 2                     The Fountainhead   180464       36772        6647
# 3                     Northern pintail   218361       13230        2453
# 4                    Manhattan Project    19603      101197       18039
# ...                                ...      ...         ...         ...
# 5195     Party of Democratic Kampuchea   265468        1927         323
# 5196             Minawara and Multultu    95240         421          83
# 5197  Theophylline/ephedra/hydroxyzine   262652         282          54
# 5198            Channel Lake, Illinois   111450        2336         499
# 5199                  Politics of Guam    12151        3271         550
#
#       sentence_count  syllable_count  complex_word_count  section_count  \
# ...

# %%
df['char_count'].nlargest(5).index.tolist()
# Out:
# [3203, 2751, 3244, 1776, 3024]

# %%
df.columns
# Out:
# Index(['title', 'page_id', 'char_count', 'word_count', 'sentence_count',
#        'syllable_count', 'complex_word_count', 'section_count',
#        'subsection_count', 'paragraph_count', 'mean_section_size',
#        'mean_paragraph_size', 'longest_section_size', 'shortest_section_size',
#        'abstract_size', 'abstract_text_ratio', 'citation_count',
#        'citation_per_text', 'external_link_count', 'internal_link_count',
#        'link_per_text', 'image_count', 'image_per_text', 'infobox',
#        'mean_sentence_size', 'largest_sentence_size', 'shortest_sentence_size',
#        'question_count', 'exclamation_count', 'pronoun_start_count', 'ARI',
#        'CLI', 'FRE', 'FKG', 'GFI', 'LIX', 'SMOG', 'article_age_days',
#        'num_edits', 'num_editors', 'num_registered_editors',
#        'num_anonymous_editors', 'num_occasional_editors', 'review_per_day',
#        'review_per_user', 'discussion_count', 'revert_count', 'quality'],
#       dtype='object')

# %%
all_index = []

# %%
all_index.extend(df['char_count'].nlargest(5).index.tolist())
all_index.extend(df['word_count'].nlargest(5).index.tolist())
all_index.extend(df['sentence_count'].nlargest(5).index.tolist())
all_index.extend(df['syllable_count'].nlargest(5).index.tolist())
all_index.extend(df['complex_word_count'].nlargest(5).index.tolist())

all_index.extend(df['section_count'].nlargest(5).index.tolist())
all_index.extend(df['subsection_count'].nlargest(5).index.tolist())
all_index.extend(df['paragraph_count'].nlargest(5).index.tolist())
all_index.extend(df['mean_section_size'].nlargest(5).index.tolist())
all_index.extend(df['mean_paragraph_size'].nlargest(5).index.tolist())
all_index.extend(df['longest_section_size'].nlargest(5).index.tolist())
all_index.extend(df['shortest_section_size'].nlargest(5).index.tolist())
all_index.extend(df['abstract_size'].nlargest(5).index.tolist())
all_index.extend(df['abstract_text_ratio'].nlargest(5).index.tolist())
all_index.extend(df['citation_count'].nlargest(5).index.tolist())
all_index.extend(df['citation_per_text'].nlargest(5).index.tolist())
all_index.extend(df['external_link_count'].nlargest(5).index.tolist())
all_index.extend(df['internal_link_count'].nlargest(5).index.tolist())
all_index.extend(df['link_per_text'].nlargest(5).index.tolist())
all_index.extend(df['image_count'].nlargest(5).index.tolist())
all_index.extend(df['image_per_text'].nlargest(5).index.tolist())
all_index.extend(df['infobox'].nlargest(5).index.tolist())

all_index.extend(df['mean_sentence_size'].nlargest(5).index.tolist())
all_index.extend(df['largest_sentence_size'].nlargest(5).index.tolist())
all_index.extend(df['shortest_sentence_size'].nlargest(5).index.tolist())
all_index.extend(df['question_count'].nlargest(5).index.tolist())
all_index.extend(df['exclamation_count'].nlargest(5).index.tolist())
all_index.extend(df['pronoun_start_count'].nlargest(5).index.tolist())

all_index.extend(df['ARI'].nlargest(5).index.tolist())
all_index.extend(df['CLI'].nlargest(5).index.tolist())
all_index.extend(df['FRE'].nsmallest(5).index.tolist())
all_index.extend(df['FKG'].nlargest(5).index.tolist())
all_index.extend(df['GFI'].nlargest(5).index.tolist())
all_index.extend(df['LIX'].nlargest(5).index.tolist())
all_index.extend(df['SMOG'].nlargest(5).index.tolist())

all_index.extend(df['num_edits'].nlargest(5).index.tolist())
all_index.extend(df['num_editors'].nlargest(5).index.tolist())
all_index.extend(df['num_registered_editors'].nlargest(5).index.tolist())
all_index.extend(df['num_anonymous_editors'].nlargest(5).index.tolist())
all_index.extend(df['num_occasional_editors'].nlargest(5).index.tolist())
all_index.extend(df['review_per_day'].nlargest(5).index.tolist())
all_index.extend(df['review_per_user'].nlargest(5).index.tolist())
all_index.extend(df['discussion_count'].nlargest(5).index.tolist())
all_index.extend(df['revert_count'].nlargest(5).index.tolist())

# %%
all_index = list(set(all_index))

# %%
df.drop(all_index, inplace=True)
df
# Out:
#                                          title  page_id  char_count  \
# 3                             Northern pintail   218361       13230
# 6                               Humpback whale   231728       25494
# 7                            League of Nations    17926       77636
# 8                          Edward I of England    46373       68091
# 9     1880 United States presidential election    40525       30240
# ...                                        ...      ...         ...
# 5195             Party of Democratic Kampuchea   265468        1927
# 5196                     Minawara and Multultu    95240         421
# 5197          Theophylline/ephedra/hydroxyzine   262652         282
# 5198                    Channel Lake, Illinois   111450        2336
# 5199                          Politics of Guam    12151        3271
#
#       word_count  sentence_count  syllable_count  complex_word_count  \
# 3           2453              66            3181                 226
# ...

# %%
df.reset_index(drop=True, inplace=True)

# %%
df.to_csv('/content/drive/MyDrive/학교/Dissertation/Data Preprocessing/features_outlier.csv')
