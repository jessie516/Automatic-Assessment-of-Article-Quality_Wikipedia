# %%
import pandas as pd

# %% [markdown]
# ### Dataset1

# %% [markdown]
# - https://github.com/vinhqdang/wikipedia_analysis

# %%
data = pd.read_csv('all_data.csv')
data
# Out:
#         1073624   16845228 Start  51.18  11.1  14.6  19.43  18.4  10.51    60  \
# 0       1392765   19906084  Stub  52.87   8.4   8.8  19.24  14.5  10.55    13
# 1       1533556   23751187  Stub  17.00  13.9  14.6  29.33  23.1  13.00    20
# 2       1590197   23751854  Stub  25.46  12.7  13.0  28.58  22.5  13.00    20
# 3       1978019   25867452  Stub  36.28  12.7  14.6  22.45  20.0  11.02    30
# 4       2605056   26162291  Stub  58.28   8.4  11.2  21.05  17.0  10.31    21
# ...         ...        ...   ...    ...   ...   ...    ...   ...    ...   ...
# 20483    370506  570108205    FA  31.21  14.6  14.6  25.88  25.0   9.34  1383
# 20484   6964665  433472294    FA   2.44  17.4  15.9  33.99  29.4   9.81   710
# 20485  25655277  370219279    FA  -2.97  17.4  14.6  34.04  28.4  10.15   404
# 20486    341496  293418178    FA  27.15  16.2  17.1  24.20  25.9   9.40  1059
# 20487   3254467  535457907    FA   9.89  16.6  15.9  31.15  27.9  10.01   940
#
# ...

# %%
train = pd.read_csv('all_score_train.csv')
train
# Out:
#          pageid      revid user_rating  flesch_reading_ease  \
# 0       1073624   16845228       Start                51.18
# 1       1392765   19906084        Stub                52.87
# 2       1533556   23751187        Stub                17.00
# 3       1590197   23751854        Stub                25.46
# 4       1978019   25867452        Stub                36.28
# ...         ...        ...         ...                  ...
# 20484    370506  570108205          FA                31.21
# 20485   6964665  433472294          FA                 2.44
# 20486  25655277  370219279          FA                -2.97
# 20487    341496  293418178          FA                27.15
# 20488   3254467  535457907          FA                 9.89
#
#        flesch_kincaid_grade  smog_index  coleman_liau_index  \
# 0                      11.1        14.6               19.43
# 1                       8.4         8.8               19.24
# 2                      13.9        14.6               29.33
# ...

# %%
test = pd.read_csv('all_score_test.csv')
test
# Out:
#         pageid      revid user_rating  flesch_reading_ease  \
# 0     19401230  239823824        Stub                55.58
# 1     27460152  396542120        Stub                55.24
# 2     14879356  185658128        Stub                47.79
# 3     28104383  404087430        Stub               -12.78
# 4      3820673   39290801        Stub                65.05
# ...        ...        ...         ...                  ...
# 2043    370506  570108205          FA                31.21
# 2044   6964665  433472294          FA                 2.44
# 2045  25655277  370219279          FA                -2.97
# 2046    341496  293418178          FA                27.15
# 2047   3254467  535457907          FA                 9.89
#
#       flesch_kincaid_grade  smog_index  coleman_liau_index  \
# 0                     11.5        14.6               24.08
# 1                     15.7        18.2               27.11
# 2                     10.3        14.6               29.40
# ...

# %%
train['user_rating'].value_counts()
# Out:
# user_rating
# Stub     4273
# Start    4110
# C        3322
# B        3209
# GA       3160
# FA       2415
# Name: count, dtype: int64

# %%
train.columns
# Out:
# Index(['pageid', 'revid', 'user_rating', 'flesch_reading_ease',
#        'flesch_kincaid_grade', 'smog_index', 'coleman_liau_index',
#        'automated_readability_index', 'dale_chall_readability_score',
#        'difficult_words', 'linsear_write_formula', 'gunning_fog',
#        'readability_consensus', 'infonoisescore', 'logcontentlength',
#        'logreferences', 'logpagelinks', 'numimageslength', 'num_citetemplates',
#        'lognoncitetemplates', 'num_categories', 'hasinfobox', 'lvl2headings',
#        'lvl3heading'],
#       dtype='object')

# %% [markdown]
# ### Dataset2

# %% [markdown]
# - https://ikr3.disco.unimib.it/wikipediadataset/
# - https://github.com/ikr3-lab/wikipediadataset
#
# - Automatically Assessing the Quality of Wikipedia Contents 2019
# - Feature Anaysis for Assessing the Quality of Wikipedia Articles through Spervised Classification 2018

# %% [markdown]
# __MH1__
# - FA vs. non-Fa
# - 400 each class

# %%
MH1 = pd.read_csv('MH_FA_NON-FA_Dataset.csv')
MH1
# Out:
#      characterCount  wordCount  syllableCount  sentenceCount  sectionCount  \
# 0             14010       2848           4552            106             4
# 1             14295       2951           4676            100             5
# 2             32047       6616          10477            228            13
# 3             46422       9045          15745            389            16
# 4             10809       2105           3673             90             5
# ..              ...        ...            ...            ...           ...
# 795            1354        303            456             13             3
# 796             957        194            346             11             2
# 797             214         41             71              3             1
# 798             413         83            148              3             2
# 799            1903        395            665             22             4
#
# ...

# %% [markdown]
# __MH2__
# - all 7 classes
# - 400 each class

# %%
MH2 = pd.read_csv('MHDataset.csv')
MH2
# Out:
#       characterCount  wordCount  syllableCount  sentenceCount  sectionCount  \
# 0              14010       2848           4552            106             4
# 1              14295       2951           4676            100             5
# 2              32047       6616          10477            228            13
# 3              46422       9045          15745            389            16
# 4              10809       2105           3673             90             5
# ...              ...        ...            ...            ...           ...
# 2795             319         62            108              3             1
# 2796             103         21             33              2             1
# 2797             704        162            256              9             1
# 2798             366         75            136              6             2
# 2799            4383        926           1487             37             4
#
# ...

# %% [markdown]
# __MH3__
# - all 7 classes
# - 400 each class

# %%
MH3 = pd.read_csv('MHParallelDataset.csv')
MH3
# Out:
#       characterCount  wordCount  syllableCount  sentenceCount  sectionCount  \
# 0              13672       2772           4444            105             4
# 1              14040       2911           4601            100             5
# 2              31997       6592          10449            227            13
# 3              44037       8583          14944            367            16
# 4               9938       1952           3383             79             5
# ...              ...        ...            ...            ...           ...
# 2795             319         62            108              3             1
# 2796             103         21             33              2             1
# 2797             616        146            228              7             1
# 2798             403         85            151              6             2
# 2799             627        125            210              8             1
#
# ...

# %%
MH3.columns.tolist()
# Out:
# ['characterCount',
#  'wordCount',
#  'syllableCount',
#  'sentenceCount',
#  'sectionCount',
#  'subsectionCount',
#  'paragraphCount',
#  'meanSectionSize',
#  'meanParagraphSize',
#  'largestSectionSize',
#  'shortestSectionSize',
#  'largestShortestSectionRatio',
#  'sectionSizeStandardDeviation',
#  'meanOfSubsectionsPerSection',
#  'abstractSize',
#  'abstractSizeArtcileLengthRatio',
#  'citationCount',
#  'citationCountPerTextLength',
#  'citationCountPerSection',
#  'externalLinksCount',
#  'externalLinksPerTextLength',
#  'externalLinksPerSection',
#  'imageCount',
#  'imagePerTextLength',
#  'imagePerSection',
#  'meanSentenceSize',
#  'largestSentenceSize',
#  'shortestSentenceSize',
#  'largeSentenceRate',
#  'shortSentenceRate',
#  'questionCount',
#  'questionRatio',
#  'exclamationCount',
#  'exclamationRatio',
#  'toBeVerbCount',
#  'toBeVerbRatio',
#  'toBeVerbPerSentence',
#  'toBeVerbRate',
#  'modalAuxiliaryVerbCount',
#  'modalAuxiliaryVerbsRatio',
# ...

# %% [markdown]
# 'characterCount', 'wordCount', 'syllableCount', 'sentenceCount', 'sectionCount', 'subsectionCount', 'paragraphCount', 'meanSectionSize', 'meanParagraphSize', 'largestSectionSize', 'shortestSectionSize', 'largestShortestSectionRatio', 'sectionSizeStandardDeviation', 'meanOfSubsectionsPerSection', 'abstractSize', 'abstractSizeArtcileLengthRatio', 'citationCount', 'citationCountPerTextLength', 'citationCountPerSection', 'externalLinksCount', 'externalLinksPerTextLength', 'externalLinksPerSection', 'imageCount', 'imagePerTextLength', 'imagePerSection', 'meanSentenceSize', 'largestSentenceSize', 'shortestSentenceSize', 'largeSentenceRate', 'shortSentenceRate', 'questionCount', 'questionRatio', 'exclamationCount', 'exclamationRatio', 'toBeVerbCount', 'toBeVerbRatio', 'toBeVerbPerSentence', 'toBeVerbRate', 'modalAuxiliaryVerbCount', 'modalAuxiliaryVerbsRatio', 'modalAuxiliaryVerbsPerSentence', 'modalAuxiliaryVerbsRate', 'passiveVoiceCount', 'passiveVoiceRatio', 'passiveVoicePerSentence', 'passiveVoiceRate', 'numberOfSentencesThatStartWithACoordinatingConjunction', 'numberOfSentencesThatStartWithADeterminer', 'numberOfSentencesThatStartWithASubordinatingPrepositionOrConjunction', 'numberOfSentencesThatStartWithAnAdjective', 'numberOfSentencesThatStartWithANoun', 'numberOfSentencesThatStartWithAPronoun', 'numberOfSentencesThatStartWithAnAdverb', 'numberOfSentencesThatStartWithAnArticle', 'numberOfSentencesThatStartWithACoordinatingConjunctionRatio', 'numberOfSentencesThatStartWithADeterminerRatio', 'numberOfSentencesThatStartWithASubordinatingPrepositionOrConjunctionRatio', 'numberOfSentencesThatStartWithAnAdjectiveRatio', 'numberOfSentencesThatStartWithANounRatio', 'numberOfSentencesThatStartWithAPronounRatio', 'numberOfSentencesThatStartWithAnAdverbRatio', 'numberOfSentencesThatStartWithAnArticleRatio', 'automatedReadabilityIndex', 'colemanLiauIndex', 'fleshReadingEase', 'fleschKincaidGradeLevel', 'gunningFogIndex', 'lasbarhetsIndex', 'smogGrading', 'daleChallReadabilityFormula', 'differentWordCount', 'differentWordsPerSentence', 'differentWordsRate', 'nounCount', 'nounsPerSentence', 'nounsRate', 'differentNounCount', 'differentNounsPerSentence', 'differentNounsRate', 'differentNounsDifferentWordsRatio', 'verbCount', 'verbsPerSentence', 'verbsRate', 'differentVerbCount', 'differentVerbsPerSentence', 'differentVerbsRate', 'differentVerbsDifferentWordsRatio', 'pronounCount', 'pronounsPerSentence', 'pronounsRate', 'differentPronounCount', 'differentPronounsPerSentence', 'differentPronounsRate', 'differentPronounsDifferentWordsRatio', 'adjectiveCount', 'adjectivesPerSentence', 'adjectivesRate', 'differentAdjectiveCount', 'differentAdjectivesPerSentence', 'differentAdjectivesRate', 'differentAdjectivesDifferentWordsRatio', 'adverbCount', 'adverbsPerSentence', 'adverbsRate', 'differentAdverbCount', 'differentAdverbsPerSentence', 'differentAdverbsRate', 'differentAdverbsDifferentWordsRatio', 'coordinatingConjunctionCount', 'coordinatingConjunctionsPerSentence', 'coordinatingConjunctionsRate', 'differentCoordinatingConjunctionCount', 'differentCoordinatingConjunctionsPerSentence', 'differentCoordinatingConjunctionsRate', 'differentCoordinatingConjunctionsDifferentWordsRatio', 'subordinatingPrepositionAndConjunctionCount', 'subordinatingPrepositionsAndConjunctionsPerSentence', 'subordinatingPrepositionsAndConjunctionsRate', 'differentSubordinatingPrepositionAndConjunctionCount', 'differentSubordinatingPrepositionsAndConjunctionsPerSentence', 'differentSubordinatingPrepositionsAndConjunctionsRate', 'differentSubordinatingPrepositionsAndConjunctionsDifferentWordsRatio', 'syllablesPerWord', 'charactersPerWord', 'NNP,NNP,NNP', 'VBD,DT,JJ', 'IN,DT,NNP', 'NNP,IN,DT', 'DT,NNP,NNP', 'JJ,NN,IN', 'NN,IN,DT', 'IN,DT,NN', 'NN,IN,NNP', 'IN,NNP,NNP', 'NNP,VBD,DT', 'VBD,DT,NN', 'DT,NN,IN', 'VBD,VBN,IN', 'NNP,NNP,VBD', 'IN,NN,IN', 'NNP,NNP,IN', 'NNP,IN,NNP', 'VBD,IN,DT', 'IN,DT,JJ', 'JJ,NNS,IN', 'DT,JJ,NN', 'IN,DT,NNS', 'IN,CD,NNP', 'VBN,IN,DT', 'DT,NN,NN', 'IN,PRP$,NN', 'NNP,VBD,VBN', 'NNP,CC,NNP', 'NNS,IN,DT', 'NN,IN,NN', 'DT,NN,VBD', 'NN,VBD,VBN', 'TO,VB,DT', 'NNP,POS,NN', 'ter', 'er_', '_wa', 'was', 'as_', 's_a', '_a_', 'an_', 'e_a', '_an', 'and', 'nd_', '_re', 'ent', '_of', 'of_', 'f_t', '_th', 'the', 'he_', 'on_', ',_a', 'at_', 'ed_', '_on', 'n_t', 'or_', 'ing', 'ng_', '_in', 'in_', 'd_t', 'd_a', '_he', '_to', 'ted', 'th_', 'al_', 'es_', 'ate', '_co', 'ion', 'ere', '_fo', 'for', 's,_', 'to_', 'ati', 'st_', 're_', '_be', 'ly_', 'her', '_hi', 'his', 'is_', 'e_t', 'en_', 'e_o', 't_t', 'tio', '_Th', 'age', 'agePerReview', 'reviewPerDay', 'reviewsPerUser', 'reviewsPerUserStdDev', 'discussionCount', 'reviewCount', 'registeredReviewCount', 'anonymouseReviewCount', 'registeredReviewRate', 'anonymouseReviewRate', 'registeredAnonymouseReviewRatio', 'userCount', 'occasionalUserCount', 'occasionalUserRate', 'registeredUserCount', 'anonymouseUserCount', 'registerdAnonymouseUserRatio', 'registeredUserRate', 'anonymouseUserRate', 'revertCount', 'revertReviewRatio', 'diversity', 'modifiedLinesRate', 'mostActiveUsersReviewCount', 'mostActiveUsersReviewRate', 'lastThreeMonthsReviewCount', 'lastThreeMonthsReviewRate', 'qualityClass'

# %% [markdown]
# __MH4__
# - FA, GA, and A vs. other classes
# - 1200 each class

# %%
MH4 = pd.read_csv('MHTwoClassesDataset.csv')
MH4
# Out:
#       characterCount  wordCount  syllableCount  sentenceCount  sectionCount  \
# 0              14010       2848           4552            106             4
# 1              14295       2951           4676            100             5
# 2              32047       6616          10477            228            13
# 3              46422       9045          15745            389            16
# 4              10809       2105           3673             90             5
# ...              ...        ...            ...            ...           ...
# 2395             586        122            197              8             1
# 2396            4851        973           1661             43             6
# 2397             479        107            172              6             1
# 2398             272         57             99              5             1
# 2399             449         96            155              4             2
#
# ...

# %%
MH4.columns.tolist()
# Out:
# ['characterCount',
#  'wordCount',
#  'syllableCount',
#  'sentenceCount',
#  'sectionCount',
#  'subsectionCount',
#  'paragraphCount',
#  'meanSectionSize',
#  'meanParagraphSize',
#  'largestSectionSize',
#  'shortestSectionSize',
#  'largestShortestSectionRatio',
#  'sectionSizeStandardDeviation',
#  'meanOfSubsectionsPerSection',
#  'abstractSize',
#  'abstractSizeArtcileLengthRatio',
#  'citationCount',
#  'citationCountPerTextLength',
#  'citationCountPerSection',
#  'externalLinksCount',
#  'externalLinksPerTextLength',
#  'externalLinksPerSection',
#  'imageCount',
#  'imagePerTextLength',
#  'imagePerSection',
#  'meanSentenceSize',
#  'largestSentenceSize',
#  'shortestSentenceSize',
#  'largeSentenceRate',
#  'shortSentenceRate',
#  'questionCount',
#  'questionRatio',
#  'exclamationCount',
#  'exclamationRatio',
#  'toBeVerbCount',
#  'toBeVerbRatio',
#  'toBeVerbPerSentence',
#  'toBeVerbRate',
#  'modalAuxiliaryVerbCount',
#  'modalAuxiliaryVerbsRatio',
# ...

# %% [markdown]
# 'characterCount', 'wordCount', 'syllableCount', 'sentenceCount', 'sectionCount', 'subsectionCount', 'paragraphCount', 'meanSectionSize', 'meanParagraphSize', 'largestSectionSize', 'shortestSectionSize', 'largestShortestSectionRatio', 'sectionSizeStandardDeviation', 'meanOfSubsectionsPerSection', 'abstractSize', 'abstractSizeArtcileLengthRatio', 'citationCount', 'citationCountPerTextLength', 'citationCountPerSection', 'externalLinksCount', 'externalLinksPerTextLength', 'externalLinksPerSection', 'imageCount', 'imagePerTextLength', 'imagePerSection', 'meanSentenceSize', 'largestSentenceSize', 'shortestSentenceSize', 'largeSentenceRate', 'shortSentenceRate', 'questionCount', 'questionRatio', 'exclamationCount', 'exclamationRatio', 'toBeVerbCount', 'toBeVerbRatio', 'toBeVerbPerSentence', 'toBeVerbRate', 'modalAuxiliaryVerbCount', 'modalAuxiliaryVerbsRatio', 'modalAuxiliaryVerbsPerSentence', 'modalAuxiliaryVerbsRate', 'passiveVoiceCount', 'passiveVoiceRatio', 'passiveVoicePerSentence', 'passiveVoiceRate', 'numberOfSentencesThatStartWithACoordinatingConjunction', 'numberOfSentencesThatStartWithADeterminer', 'numberOfSentencesThatStartWithASubordinatingPrepositionOrConjunction', 'numberOfSentencesThatStartWithAnAdjective', 'numberOfSentencesThatStartWithANoun', 'numberOfSentencesThatStartWithAPronoun', 'numberOfSentencesThatStartWithAnAdverb', 'numberOfSentencesThatStartWithAnArticle', 'numberOfSentencesThatStartWithACoordinatingConjunctionRatio', 'numberOfSentencesThatStartWithADeterminerRatio', 'numberOfSentencesThatStartWithASubordinatingPrepositionOrConjunctionRatio', 'numberOfSentencesThatStartWithAnAdjectiveRatio', 'numberOfSentencesThatStartWithANounRatio', 'numberOfSentencesThatStartWithAPronounRatio', 'numberOfSentencesThatStartWithAnAdverbRatio', 'numberOfSentencesThatStartWithAnArticleRatio', 'automatedReadabilityIndex', 'colemanLiauIndex', 'fleshReadingEase', 'fleschKincaidGradeLevel', 'gunningFogIndex', 'lasbarhetsIndex', 'smogGrading', 'daleChallReadabilityFormula', 'differentWordCount', 'differentWordsPerSentence', 'differentWordsRate', 'nounCount', 'nounsPerSentence', 'nounsRate', 'differentNounCount', 'differentNounsPerSentence', 'differentNounsRate', 'differentNounsDifferentWordsRatio', 'verbCount', 'verbsPerSentence', 'verbsRate', 'differentVerbCount', 'differentVerbsPerSentence', 'differentVerbsRate', 'differentVerbsDifferentWordsRatio', 'pronounCount', 'pronounsPerSentence', 'pronounsRate', 'differentPronounCount', 'differentPronounsPerSentence', 'differentPronounsRate', 'differentPronounsDifferentWordsRatio', 'adjectiveCount', 'adjectivesPerSentence', 'adjectivesRate', 'differentAdjectiveCount', 'differentAdjectivesPerSentence', 'differentAdjectivesRate', 'differentAdjectivesDifferentWordsRatio', 'adverbCount', 'adverbsPerSentence', 'adverbsRate', 'differentAdverbCount', 'differentAdverbsPerSentence', 'differentAdverbsRate', 'differentAdverbsDifferentWordsRatio', 'coordinatingConjunctionCount', 'coordinatingConjunctionsPerSentence', 'coordinatingConjunctionsRate', 'differentCoordinatingConjunctionCount', 'differentCoordinatingConjunctionsPerSentence', 'differentCoordinatingConjunctionsRate', 'differentCoordinatingConjunctionsDifferentWordsRatio', 'subordinatingPrepositionAndConjunctionCount', 'subordinatingPrepositionsAndConjunctionsPerSentence', 'subordinatingPrepositionsAndConjunctionsRate', 'differentSubordinatingPrepositionAndConjunctionCount', 'differentSubordinatingPrepositionsAndConjunctionsPerSentence', 'differentSubordinatingPrepositionsAndConjunctionsRate', 'differentSubordinatingPrepositionsAndConjunctionsDifferentWordsRatio', 'syllablesPerWord', 'charactersPerWord', 'NNP,NNP,NNP', 'VBD,DT,JJ', 'IN,DT,NNP', 'NNP,IN,DT', 'DT,NNP,NNP', 'JJ,NN,IN', 'NN,IN,DT', 'IN,DT,NN', 'NN,IN,NNP', 'IN,NNP,NNP', 'NNP,VBD,DT', 'VBD,DT,NN', 'DT,NN,IN', 'VBD,VBN,IN', 'NNP,NNP,VBD', 'IN,NN,IN', 'NNP,NNP,IN', 'NNP,IN,NNP', 'VBD,IN,DT', 'IN,DT,JJ', 'JJ,NNS,IN', 'DT,JJ,NN', 'IN,DT,NNS', 'IN,CD,NNP', 'VBN,IN,DT', 'DT,NN,NN', 'IN,PRP$,NN', 'NNP,VBD,VBN', 'NNP,CC,NNP', 'NNS,IN,DT', 'NN,IN,NN', 'DT,NN,VBD', 'NN,VBD,VBN', 'TO,VB,DT', 'NNP,POS,NN', 'ter', 'er_', '_wa', 'was', 'as_', 's_a', '_a_', 'an_', 'e_a', '_an', 'and', 'nd_', '_re', 'ent', '_of', 'of_', 'f_t', '_th', 'the', 'he_', 'on_', ',_a', 'at_', 'ed_', '_on', 'n_t', 'or_', 'ing', 'ng_', '_in', 'in_', 'd_t', 'd_a', '_he', '_to', 'ted', 'th_', 'al_', 'es_', 'ate', '_co', 'ion', 'ere', '_fo', 'for', 's,_', 'to_', 'ati', 'st_', 're_', '_be', 'ly_', 'her', '_hi', 'his', 'is_', 'e_t', 'en_', 'e_o', 't_t', 'tio', '_Th', 'age', 'agePerReview', 'reviewPerDay', 'reviewsPerUser', 'reviewsPerUserStdDev', 'discussionCount', 'reviewCount', 'registeredReviewCount', 'anonymouseReviewCount', 'registeredReviewRate', 'anonymouseReviewRate', 'registeredAnonymouseReviewRatio', 'userCount', 'occasionalUserCount', 'occasionalUserRate', 'registeredUserCount', 'anonymouseUserCount', 'registerdAnonymouseUserRatio', 'registeredUserRate', 'anonymouseUserRate', 'revertCount', 'revertReviewRatio', 'diversity', 'modifiedLinesRate', 'mostActiveUsersReviewCount', 'mostActiveUsersReviewRate', 'occasionalUsersReviewCount', 'occasionalUsersReviewRate', 'lastThreeMonthsReviewCount', 'lastThreeMonthsReviewRate', 'pageRank', 'indegree', 'outdegree', 'assortativity_inin', 'assortativity_inout', 'assortativity_outin', 'assortativity_outout', 'localClusteringCoefficient', 'reciprocity', 'linkCount', 'translationCount', 'probReviewRank', 'qualityClass'

# %% [markdown]
# ### Dataset3

# %% [markdown]
# - https://github.com/MOAAS/WikiQuality
# - https://github.com/MOAAS/WikiQuality/blob/main/ml/datasets/README.md
# - Real-time prediction of Wikipedia articles' quality 2022

# %%
multi_en = pd.read_csv('multi-en-11096-csrh.csv')
multi_en
# Out:
#                                         Title    CC   CW  CSN  CS        CMSL  \
# 0      Part XVII of the Albanian Constitution  1582  267   19   2  774.000000
# 1                            1975 Pacific Cup  2866  362    8   4  706.250000
# 2                              Whitney Church  1396  229   13   2  688.000000
# 3                                     Veresna   510   62    5   3  150.000000
# 4                                   Chebabius   455   49    1   1  455.000000
# ...                                       ...   ...  ...  ...  ..         ...
# 11091                             James Luson   249   28    2   3   66.666667
# 11092                              Junpai A50   339   57    4   2  162.000000
# 11093                  Mary Catherine Bateson  4080  636   28   6  664.166667
# 11094                        Saldula pallipes   366   51    3   2  175.000000
# 11095                            Gebhardshain   707  105    9   1  707.000000
#
# ...

# %%
multi_en['Quality'].value_counts()
# Out:
# Quality
# F     6251
# D     3860
# C      725
# B      199
# A       48
# A+      13
# Name: count, dtype: int64

# %%
multi_en.columns.tolist()
# Out:
# ['Title',
#  'CC',
#  'CW',
#  'CSN',
#  'CS',
#  'CMSL',
#  'CP',
#  'CMPL',
#  'CLSL',
#  'CSSL',
#  'CSTDSL',
#  'CLSSR',
#  'CB',
#  'CBPS',
#  'CNL',
#  'CNLTLR',
#  'CR',
#  'CCC',
#  'CCCPC',
#  'CCCPS',
#  'CEL',
#  'CELPS',
#  'CELPC',
#  'CIL',
#  'CILPC',
#  'CI',
#  'CIPC',
#  'CIPS',
#  'CL3',
#  'CIB',
#  'CCT',
#  'CNCT',
#  'CTB',
#  'CUCT',
#  'SSLS',
#  'SSSS',
#  'SMSS',
#  'SLSR',
#  'SSSR',
#  'SQ',
#  'SQPS',
#  'SE',
#  'SEPS',
#  'SS',
#  'SMSPW',
#  'SMCPW',
#  'SSTP',
#  'SSTART',
#  'SSTC',
#  'SSTSUB',
#  'SSTI',
#  'SSTD',
#  'SSTADJ',
#  'SSTN',
#  'SSTADV',
#  'SSTPPS',
#  'SSTARTPS',
#  'SSTCPS',
#  'SSTSUBPS',
#  'SSTDPS',
#  'SSTADJPS',
#  'SSTNPS',
#  'SSTADVPS',
#  'SMV',
#  'STB',
#  'SUW',
#  'SN',
#  'SUN',
#  'SV',
#  'SUV',
#  'SP',
#  'SUP',
#  'SADV',
#  'SUADV',
#  'SADJ',
#  'SUADJ',
#  'SCC',
#  'SUCC',
#  'SSUB',
#  'SUSUB',
#  'SMVPW',
#  'STBPW',
#  'SUWPW',
#  'SNPW',
#  'SUNPW',
#  'SVPW',
#  'SUVPW',
#  'SPPW',
#  'SUPPW',
# ...

# %% [markdown]
# 'Title', 'CC', 'CW', 'CSN', 'CS', 'CMSL', 'CP', 'CMPL', 'CLSL', 'CSSL', 'CSTDSL', 'CLSSR', 'CB', 'CBPS', 'CNL', 'CNLTLR', 'CR', 'CCC', 'CCCPC', 'CCCPS', 'CEL', 'CELPS', 'CELPC', 'CIL', 'CILPC', 'CI', 'CIPC', 'CIPS', 'CL3', 'CIB', 'CCT', 'CNCT', 'CTB', 'CUCT', 'SSLS', 'SSSS', 'SMSS', 'SLSR', 'SSSR', 'SQ', 'SQPS', 'SE', 'SEPS', 'SS', 'SMSPW', 'SMCPW', 'SSTP', 'SSTART', 'SSTC', 'SSTSUB', 'SSTI', 'SSTD', 'SSTADJ', 'SSTN', 'SSTADV', 'SSTPPS', 'SSTARTPS', 'SSTCPS', 'SSTSUBPS', 'SSTDPS', 'SSTADJPS', 'SSTNPS', 'SSTADVPS', 'SMV', 'STB', 'SUW', 'SN', 'SUN', 'SV', 'SUV', 'SP', 'SUP', 'SADV', 'SUADV', 'SADJ', 'SUADJ', 'SCC', 'SUCC', 'SSUB', 'SUSUB', 'SMVPW', 'STBPW', 'SUWPW', 'SNPW', 'SUNPW', 'SVPW', 'SUVPW', 'SPPW', 'SUPPW', 'SADVPW', 'SUADVPW', 'SADJPW', 'SUADJPW', 'SCCPW', 'SUCCPW', 'SSUBPW', 'SUSUBPW', 'STBPV', 'SUNPUW', 'SUVPUW', 'SUPPUW', 'SUADJPUW', 'SUADVPUW', 'SUCCPUW', 'SUSUBPUW', 'SWL6', 'RARI', 'RCL', 'RFRE', 'RFK', 'RGFI', 'RLBI', 'RSG', 'RDWS', 'RDC', 'RLWF', 'HA', 'HAPR', 'HRPD', 'HRPC', 'HRPCSD', 'HR', 'HC', 'HRC', 'HAC', 'HRCPC', 'HACPC', 'HRCPAC', 'HREV', 'HREVPR', 'HRML', 'HREC', 'HRECPR', 'HACT', 'HACTPR', 'HOCCPR', 'HSSLE', 'HMCL', 'Quality'

# %%
train2 = pd.read_csv('6000x6-csrhn_train.csv')
train2
# Out:
#                         Title     CC     CW  CSN  CS         CMSL  CP  \
# 0                    M-theory  37094   5604  249   6  6163.833333  98
# 1      AdS/CFT correspondence  30552   4614  198   7  4338.714286  73
# 2                       Quark  27384   4326  183   6  4548.000000  58
# 3             Richard Feynman  67103  10008  753   9  7439.111111  73
# 4               Jürgen Ehlers  21218   3150  136   5  4227.600000  34
# ...                       ...    ...    ...  ...  ..          ...  ..
# 25185          Agni Samskaram    117     16    2   1   117.000000   4
# 25186               Kheragarh    673    104   16   3   214.666667   3
# 25187                Chamarru    914    148   13   4   215.500000   7
# 25188               Ezhudesam    750    127   11   2   366.000000   3
# 25189                 Lingana    898    158   13   2   442.500000   2
#
#              CMPL   CLSL  CSSL  ...       HMCL   NT  NIN  NOUT  NASSinin  \
# ...

# %%
train2['Quality'].value_counts()
# Out:
# Quality
# FA       4200
# GA       4200
# C        4199
# Stub     4198
# B        4197
# Start    4196
# Name: count, dtype: int64

# %%
test2 = pd.read_csv('6000x6-csrhn_test.csv')
test2
# Out:
#                                                Title     CC    CW  CSN  CS  \
# 0                               Banksia sphaerocarpa  17737  2761  254   7
# 1                                    Banksia cuneata  20317  3245  209   7
# 2                                 Banksia ilicifolia  17423  2706  190   6
# 3                                Adenanthos obovatus  13456  2112  158   6
# 4                                   Epacris impressa  16227  2534  151   7
# ...                                              ...    ...   ...  ...  ..
# 10787  Sri Sangamitta Balika National School  Matale    185    29    3   1
# 10788               Aziz Democratic Workers Congress    137    24    7   1
# 10789     Sri Lankan cricket team in England in 1984    998   159    8   2
# 10790                                 Bash-Berkutovo    341    49    6   2
# 10791                                      Mom Genes    309    48    3   1
#
# ...

# %%
test2['Quality'].value_counts()
# Out:
# Quality
# FA       1800
# GA       1800
# C        1799
# B        1798
# Stub     1798
# Start    1797
# Name: count, dtype: int64

# %%
train2.columns.tolist()
# Out:
# ['Title',
#  'CC',
#  'CW',
#  'CSN',
#  'CS',
#  'CMSL',
#  'CP',
#  'CMPL',
#  'CLSL',
#  'CSSL',
#  'CSTDSL',
#  'CLSSR',
#  'CB',
#  'CBPS',
#  'CNL',
#  'CNLTLR',
#  'CR',
#  'CCC',
#  'CCCPC',
#  'CCCPS',
#  'CEL',
#  'CELPS',
#  'CELPC',
#  'CIL',
#  'CILPC',
#  'CI',
#  'CIPC',
#  'CIPS',
#  'CL3',
#  'CIB',
#  'CCT',
#  'CNCT',
#  'CTB',
#  'CUCT',
#  'SSLS',
#  'SSSS',
#  'SMSS',
#  'SLSR',
#  'SSSR',
#  'SQ',
#  'SQPS',
#  'SE',
#  'SEPS',
#  'SS',
#  'SMSPW',
#  'SMCPW',
#  'SSTP',
#  'SSTART',
#  'SSTC',
#  'SSTSUB',
#  'SSTI',
#  'SSTD',
#  'SSTADJ',
#  'SSTN',
#  'SSTADV',
#  'SSTPPS',
#  'SSTARTPS',
#  'SSTCPS',
#  'SSTSUBPS',
#  'SSTDPS',
#  'SSTADJPS',
#  'SSTNPS',
#  'SSTADVPS',
#  'SMV',
#  'STB',
#  'SUW',
#  'SN',
#  'SUN',
#  'SV',
#  'SUV',
#  'SP',
#  'SUP',
#  'SADV',
#  'SUADV',
#  'SADJ',
#  'SUADJ',
#  'SCC',
#  'SUCC',
#  'SSUB',
#  'SUSUB',
#  'SMVPW',
#  'STBPW',
#  'SUWPW',
#  'SNPW',
#  'SUNPW',
#  'SVPW',
#  'SUVPW',
#  'SPPW',
#  'SUPPW',
# ...

# %%
print(train2.columns.tolist())
# Out:
# ['Title', 'CC', 'CW', 'CSN', 'CS', 'CMSL', 'CP', 'CMPL', 'CLSL', 'CSSL', 'CSTDSL', 'CLSSR', 'CB', 'CBPS', 'CNL', 'CNLTLR', 'CR', 'CCC', 'CCCPC', 'CCCPS', 'CEL', 'CELPS', 'CELPC', 'CIL', 'CILPC', 'CI', 'CIPC', 'CIPS', 'CL3', 'CIB', 'CCT', 'CNCT', 'CTB', 'CUCT', 'SSLS', 'SSSS', 'SMSS', 'SLSR', 'SSSR', 'SQ', 'SQPS', 'SE', 'SEPS', 'SS', 'SMSPW', 'SMCPW', 'SSTP', 'SSTART', 'SSTC', 'SSTSUB', 'SSTI', 'SSTD', 'SSTADJ', 'SSTN', 'SSTADV', 'SSTPPS', 'SSTARTPS', 'SSTCPS', 'SSTSUBPS', 'SSTDPS', 'SSTADJPS', 'SSTNPS', 'SSTADVPS', 'SMV', 'STB', 'SUW', 'SN', 'SUN', 'SV', 'SUV', 'SP', 'SUP', 'SADV', 'SUADV', 'SADJ', 'SUADJ', 'SCC', 'SUCC', 'SSUB', 'SUSUB', 'SMVPW', 'STBPW', 'SUWPW', 'SNPW', 'SUNPW', 'SVPW', 'SUVPW', 'SPPW', 'SUPPW', 'SADVPW', 'SUADVPW', 'SADJPW', 'SUADJPW', 'SCCPW', 'SUCCPW', 'SSUBPW', 'SUSUBPW', 'STBPV', 'SUNPUW', 'SUVPUW', 'SUPPUW', 'SUADJPUW', 'SUADVPUW', 'SUCCPUW', 'SUSUBPUW', 'SWL6', 'RARI', 'RCL', 'RFRE', 'RFK', 'RGFI', 'RLBI', 'RSG', 'RDWS', 'RDC', 'RLWF', 'HA', 'HAPR', 'HRPD',
# ...

# %% [markdown]
# 'Title', 'CC', 'CW', 'CSN', 'CS', 'CMSL', 'CP', 'CMPL', 'CLSL', 'CSSL', 'CSTDSL', 'CLSSR', 'CB', 'CBPS', 'CNL', 'CNLTLR', 'CR', 'CCC', 'CCCPC', 'CCCPS', 'CEL', 'CELPS', 'CELPC', 'CIL', 'CILPC', 'CI', 'CIPC', 'CIPS', 'CL3', 'CIB', 'CCT', 'CNCT', 'CTB', 'CUCT', 'SSLS', 'SSSS', 'SMSS', 'SLSR', 'SSSR', 'SQ', 'SQPS', 'SE', 'SEPS', 'SS', 'SMSPW', 'SMCPW', 'SSTP', 'SSTART', 'SSTC', 'SSTSUB', 'SSTI', 'SSTD', 'SSTADJ', 'SSTN', 'SSTADV', 'SSTPPS', 'SSTARTPS', 'SSTCPS', 'SSTSUBPS', 'SSTDPS', 'SSTADJPS', 'SSTNPS', 'SSTADVPS', 'SMV', 'STB', 'SUW', 'SN', 'SUN', 'SV', 'SUV', 'SP', 'SUP', 'SADV', 'SUADV', 'SADJ', 'SUADJ', 'SCC', 'SUCC', 'SSUB', 'SUSUB', 'SMVPW', 'STBPW', 'SUWPW', 'SNPW', 'SUNPW', 'SVPW', 'SUVPW', 'SPPW', 'SUPPW', 'SADVPW', 'SUADVPW', 'SADJPW', 'SUADJPW', 'SCCPW', 'SUCCPW', 'SSUBPW', 'SUSUBPW', 'STBPV', 'SUNPUW', 'SUVPUW', 'SUPPUW', 'SUADJPUW', 'SUADVPUW', 'SUCCPUW', 'SUSUBPUW', 'SWL6', 'RARI', 'RCL', 'RFRE', 'RFK', 'RGFI', 'RLBI', 'RSG', 'RDWS', 'RDC', 'RLWF', 'HA', 'HAPR', 'HRPD', 'HRPC', 'HRPCSD', 'HR', 'HC', 'HRC', 'HAC', 'HRCPC', 'HACPC', 'HRCPAC', 'HREV', 'HREVPR', 'HRML', 'HREC', 'HRECPR', 'HACT', 'HACTPR', 'HOCCPR', 'HSSLE', 'HMCL', 'NT', 'NIN', 'NOUT', 'NASSinin', 'NASSinout', 'NASSoutin', 'NASSoutout', 'NREP', 'Quality'

# %% [markdown]
# ### Dataset4

# %% [markdown]
# - https://github.com/analuizatrz/wiki-experiments/tree/master

# %%
df1 = pd.read_csv('6-join-single-class-without-C-evolution.csv')
df1
# Out:
#                         title  pageid           past_access  \
# 0             ...In Your Eyes     NaN  2008-12-01T00:00:00Z
# 1             ...In Your Eyes     NaN  2008-11-01T00:00:00Z
# 2             ...In Your Eyes     NaN  2008-10-01T00:00:00Z
# 3             ...In Your Eyes     NaN  2008-09-01T00:00:00Z
# 4             ...In Your Eyes     NaN  2008-08-01T00:00:00Z
# ...                       ...     ...                   ...
# 8552  Cosmopolitan (cocktail)     NaN  2007-09-01T00:00:00Z
# 8553  Cosmopolitan (cocktail)     NaN  2007-08-01T00:00:00Z
# 8554  Cosmopolitan (cocktail)     NaN  2007-07-01T00:00:00Z
# 8555  Cosmopolitan (cocktail)     NaN  2007-06-01T00:00:00Z
# 8556  Cosmopolitan (cocktail)     NaN  2007-05-01T00:00:00Z
#
#              actual_access past_category actual_category  \
# 0     2009-01-01T00:00:00Z          stub            stub
# 1     2008-12-01T00:00:00Z          stub            stub
# 2     2008-11-01T00:00:00Z          stub            stub
# ...

# %%
df1['actual_category'].value_counts()
# Out:
# actual_category
# stub     1853
# start    1812
# b        1734
# fa       1528
# a         861
# ga        769
# Name: count, dtype: int64

# %%
df1['past_category'].value_counts()
# Out:
# past_category
# stub     1853
# start    1812
# b        1734
# fa       1528
# a         861
# ga        769
# Name: count, dtype: int64

# %%
df2 = pd.read_csv('6-join_multiple_class_without_C-evolution.csv')
df2
# Out:
#                 title  pageid           past_access         actual_access  \
# 0       1,3-Butadiene     NaN  2008-12-01T00:00:00Z  2009-01-01T00:00:00Z
# 1       1,3-Butadiene     NaN  2008-11-01T00:00:00Z  2008-12-01T00:00:00Z
# 2       1,3-Butadiene     NaN  2008-10-01T00:00:00Z  2008-11-01T00:00:00Z
# 3       1,3-Butadiene     NaN  2008-09-01T00:00:00Z  2008-10-01T00:00:00Z
# 4       1,3-Butadiene     NaN  2008-08-01T00:00:00Z  2008-09-01T00:00:00Z
# ...               ...     ...                   ...                   ...
# 9288  Jonathan Frakes     NaN  2007-09-01T00:00:00Z  2007-10-01T00:00:00Z
# 9289  Jonathan Frakes     NaN  2007-08-01T00:00:00Z  2007-09-01T00:00:00Z
# 9290  Jonathan Frakes     NaN  2007-07-01T00:00:00Z  2007-08-01T00:00:00Z
# 9291  Joseph Campbell     NaN  2008-01-01T00:00:00Z  2008-02-01T00:00:00Z
# 9292  Joseph Campbell     NaN  2007-12-01T00:00:00Z  2008-01-01T00:00:00Z
#
#      past_category actual_category                     past_raw_category  \
# ...

# %%
df2['actual_category'].value_counts()
# Out:
# actual_category
# ga       2786
# a        2056
# fa       1934
# b        1548
# start     754
# stub      215
# Name: count, dtype: int64

# %%
df2['past_category'].value_counts()
# Out:
# past_category
# ga       2696
# a        2116
# fa       1850
# b        1590
# start     795
# stub      246
# Name: count, dtype: int64

# %%
df1.columns.tolist()
# Out:
# ['title',
#  'pageid',
#  'past_access',
#  'actual_access',
#  'past_category',
#  'actual_category',
#  'past_raw_category',
#  'actual_raw_category',
#  'past_revision.anon',
#  'actual_revision.anon',
#  'past_revision.comment',
#  'actual_revision.comment',
#  'past_revision.commenthidden',
#  'actual_revision.commenthidden',
#  'past_revision.parentid',
#  'actual_revision.parentid',
#  'past_revision.revid',
#  'actual_revision.revid',
#  'past_revision.user',
#  'actual_revision.user',
#  'past_timestamp',
#  'actual_timestamp',
#  'delta_timestamp',
#  'past_Section count',
#  'actual_Section count',
#  'delta_Section count',
#  'past_Subsection count',
#  'actual_Subsection count',
#  'delta_Subsection count',
#  'past_Complete URL link count',
#  'actual_Complete URL link count',
#  'delta_Complete URL link count',
#  'past_Complete URL link count per section',
#  'actual_Complete URL link count per section',
#  'delta_Complete URL link count per section',
# ...

# %% [markdown]
# 'title', 'pageid', 'past_access', 'actual_access', 'past_category', 'actual_category', 'past_raw_category', 'actual_raw_category', 'past_revision.anon', 'actual_revision.anon', 'past_revision.comment', 'actual_revision.comment', 'past_revision.commenthidden', 'actual_revision.commenthidden', 'past_revision.parentid', 'actual_revision.parentid', 'past_revision.revid', 'actual_revision.revid', 'past_revision.user', 'actual_revision.user', 'past_timestamp', 'actual_timestamp', 'delta_timestamp', 'past_Section count', 'actual_Section count', 'delta_Section count', 'past_Subsection count', 'actual_Subsection count', 'delta_Subsection count', 'past_Complete URL link count', 'actual_Complete URL link count', 'delta_Complete URL link count', 'past_Complete URL link count per section', 'actual_Complete URL link count per section', 'delta_Complete URL link count per section', 'past_Complete URL link count per length', 'actual_Complete URL link count per length', 'delta_Complete URL link count per length', 'past_Relative URL link count', 'actual_Relative URL link count', 'delta_Relative URL link count', 'past_Relative URL link count per section', 'actual_Relative URL link count per section', 'delta_Relative URL link count per section', 'past_Relative URL link count per length', 'actual_Relative URL link count per length', 'delta_Relative URL link count per length', 'past_Same page link count', 'actual_Same page link count', 'delta_Same page link count', 'past_Same page link count per section', 'actual_Same page link count per section', 'delta_Same page link count per section', 'past_Same page link count per length', 'actual_Same page link count per length', 'delta_Same page link count per length', 'past_Mean section size', 'actual_Mean section size', 'delta_Mean section size', 'past_Mean subsection size', 'actual_Mean subsection size', 'delta_Mean subsection size', 'past_Largest section size', 'actual_Largest section size', 'delta_Largest section size', 'past_Shortest section size', 'actual_Shortest section size', 'delta_Shortest section size', 'past_Standard deviation of the section size', 'actual_Standard deviation of the section size', 'delta_Standard deviation of the section size', 'past_Images count', 'actual_Images count', 'delta_Images count', 'past_Images per length', 'actual_Images per length', 'delta_Images per length', 'past_Images per section', 'actual_Images per section', 'delta_Images per section', 'past_Images per subsection', 'actual_Images per subsection', 'delta_Images per subsection', 'past_Phrase count', 'actual_Phrase count', 'delta_Phrase count', 'past_Large phrase count', 'actual_Large phrase count', 'delta_Large phrase count', 'past_Paragraph count', 'actual_Paragraph count', 'delta_Paragraph count', 'past_Large paragraph count', 'actual_Large paragraph count', 'delta_Large paragraph count', 'past_Largest phrase size', 'actual_Largest phrase size', 'delta_Largest phrase size', 'past_Large phrase rate', 'actual_Large phrase rate', 'delta_Large phrase rate', 'past_Short phrase rate', 'actual_Short phrase rate', 'delta_Short phrase rate', 'past_Char Count', 'actual_Char Count', 'delta_Char Count', 'past_Word Count', 'actual_Word Count', 'delta_Word Count', 'past_Articles count', 'actual_Articles count', 'delta_Articles count', 'past_Auxiliary verbs count', 'actual_Auxiliary verbs count', 'delta_Auxiliary verbs count', 'past_Coordination conjunctions count', 'actual_Coordination conjunctions count', 'delta_Coordination conjunctions count', 'past_Correlative conjunctions count', 'actual_Correlative conjunctions count', 'delta_Correlative conjunctions count', 'past_Indefinite pronouns count', 'actual_Indefinite pronouns count', 'delta_Indefinite pronouns count', 'past_Interrogative pronouns count', 'actual_Interrogative pronouns count', 'delta_Interrogative pronouns count', 'past_Prepositions count', 'actual_Prepositions count', 'delta_Prepositions count', 'past_Pronouns count', 'actual_Pronouns count', 'delta_Pronouns count', 'past_Relative pronoums count', 'actual_Relative pronoums count', 'delta_Relative pronoums count', 'past_Subordinating conjunctions count', 'actual_Subordinating conjunctions count', 'delta_Subordinating conjunctions count', 'past_To be verbs count', 'actual_To be verbs count', 'delta_To be verbs count', 'past_Sentences starting with articles', 'actual_Sentences starting with articles', 'delta_Sentences starting with articles', 'past_Sentences starting with auxiliary verbs', 'actual_Sentences starting with auxiliary verbs', 'delta_Sentences starting with auxiliary verbs', 'past_Sentences starting with coordination conjunctions', 'actual_Sentences starting with coordination conjunctions', 'delta_Sentences starting with coordination conjunctions', 'past_Sentences starting with correlative conjunctions', 'actual_Sentences starting with correlative conjunctions', 'delta_Sentences starting with correlative conjunctions', 'past_Sentences starting with indefinite pronouns', 'actual_Sentences starting with indefinite pronouns', 'delta_Sentences starting with indefinite pronouns', 'past_Sentences starting with interrogative pronouns', 'actual_Sentences starting with interrogative pronouns', 'delta_Sentences starting with interrogative pronouns', 'past_Sentences starting with prepositions', 'actual_Sentences starting with prepositions', 'delta_Sentences starting with prepositions', 'past_Sentences starting with pronouns', 'actual_Sentences starting with pronouns', 'delta_Sentences starting with pronouns', 'past_Sentences starting with relative pronoums', 'actual_Sentences starting with relative pronoums', 'delta_Sentences starting with relative pronoums', 'past_Sentences starting with subordinating conjunctions', 'actual_Sentences starting with subordinating conjunctions', 'delta_Sentences starting with subordinating conjunctions', 'past_Sentences starting with to be verbs', 'actual_Sentences starting with to be verbs', 'delta_Sentences starting with to be verbs', 'past_ARI readability feature', 'actual_ARI readability feature', 'delta_ARI readability feature', 'past_Coleman-Liau readability feature', 'actual_Coleman-Liau readability feature', 'delta_Coleman-Liau readability feature', 'past_Flesch Reading Ease Readability Feature', 'actual_Flesch Reading Ease Readability Feature', 'delta_Flesch Reading Ease Readability Feature', 'past_Flesch Kincaid Readability Feature', 'actual_Flesch Kincaid Readability Feature', 'delta_Flesch Kincaid Readability Feature', 'past_Gunning Fog Index readability feature', 'actual_Gunning Fog Index readability feature', 'delta_Gunning Fog Index readability feature', 'past_Lasbarhetsindex readability feature', 'actual_Lasbarhetsindex readability feature', 'delta_Lasbarhetsindex readability feature', 'past_SMOG Grading readability feature', 'actual_SMOG Grading readability feature', 'delta_SMOG Grading readability feature'

# %% [markdown]
# past_category,
# actual_Section count,
# actual_Subsection count,
# actual_Complete URL link count,
# actual_Complete URL link count per section,
# actual_Complete URL link count per length,
# actual_Relative URL link count,
# actual_Relative URL link count per section,
# actual_Relative URL link count per length,
# actual_Same page link count,
# actual_Same page link count per section,
# actual_Same page link count per length,
# actual_Mean section size,
# actual_Mean subsection size,
# actual_Largest section size,
# actual_Shortest section size,
# actual_Standard deviation of the section size,
# actual_Images count,
# actual_Images per length,
# actual_Images per section,
# actual_Images per subsection,
# actual_Phrase count,
# actual_Large phrase count,
# actual_Paragraph count,
# actual_Large paragraph count,
# actual_Largest phrase size,
# actual_Large phrase rate,
# actual_Short phrase rate,
# actual_Char Count,
# actual_Word Count,
# actual_Articles count,
# actual_Auxiliary verbs count,
# actual_Coordination conjunctions count,
# actual_Correlative conjunctions count,
# actual_Indefinite pronouns count,
# actual_Interrogative pronouns count,
# actual_Prepositions count,
# actual_Pronouns count,
# actual_Relative pronoums count,
# actual_Subordinating conjunctions count,
# actual_To be verbs count,
# actual_Sentences starting with articles,
# actual_Sentences starting with auxiliary verbs,
# actual_Sentences starting with coordination conjunctions,
# actual_Sentences starting with correlative conjunctions,
# actual_Sentences starting with indefinite pronouns,
# actual_Sentences starting with interrogative pronouns,
# actual_Sentences starting with prepositions,
# actual_Sentences starting with pronouns,
# actual_Sentences starting with relative pronoums,
# actual_Sentences starting with subordinating conjunctions,
# actual_Sentences starting with to be verbs,
# actual_ARI readability feature,
# actual_Coleman-Liau readability feature,
# actual_Flesch Reading Ease Readability Feature,
# actual_Flesch Kincaid Readability Feature,
# actual_Gunning Fog Index readability feature,
# actual_Lasbarhetsindex readability feature,
# actual_SMOG Grading readability feature
