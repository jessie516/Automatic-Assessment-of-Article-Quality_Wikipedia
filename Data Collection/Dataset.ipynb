# %%
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Drive already mounted at /content/drive; to attempt to forcibly remount, call drive.mount("/content/drive", force_remount=True).

# %%
import pandas as pd

# %%
df = pd.read_csv('/content/drive/MyDrive/학교/Dissertation/Data Collection/selected.csv')
df.drop(['Unnamed: 0'], axis=1, inplace=True)
df
# Out:
#         page_id_text            title  \
# 0                 12        Anarchism
# 1                 39           Albedo
# 2                290                A
# 3                303          Alabama
# 4                305         Achilles
# ...              ...              ...
# 143280        311306      Boch Center
# 143281        311312     Wang Theatre
# 143282        311315  Shubert Theatre
# 143283        311318    Reginald Hill
# 143284         49244              NaN
#
#                                                      text quality_text  \
# 0       {{short description|Political philosophy and m...           GA
# 1       {{Short description|Ratio of how much light is...          NaN
# 2       {{Short description|First letter of the Latin ...          NaN
# 3       {{Short description|U.S. state}}\n{{about|the ...          NaN
# 4       {{short description|Greek mythological hero}}\...          NaN
# ...                                                   ...          ...
# 143280  {{Infobox venue\n| name                   = Th...          NaN
# 143281  {{Short description|Theater in Boston, Massach...          NaN
# 143282  '''Shubert Theatre''' or '''Shubert Theater'''...          NaN
# 143283  {{Short description|British crime writer}}\n{{...          NaN
# 143284  {{Short description|Value for unrepresentable ...          NaN
#
#         page_id_api quality_api
# 0                12          GA
# 1                39         NaN
# 2               290           C
# 3               303           B
# 4               305           C
# ...             ...         ...
# 143280       311306         NaN
# 143281       311312         NaN
# 143282       311315         NaN
# 143283       311318         NaN
# 143284            0         NaN
#
# [143285 rows x 6 columns]

# %% [markdown]
# - 'page_id_text' and 'page_id_api' do not match

# %%
df[df['page_id_text']!=df['page_id_api']]
# Out:
#         page_id_text                                              title  \
# 1840            4266                            Binary search algorithm
# 5684           11781                                         Frisian(s)
# 14062          28162             List of nearest stars and brown dwarfs
# 16991          34488                                  Chang Hsueh-liang
# 22433          43303                               Mosaic (web browser)
# 25574          50027                                        Bay of Pigs
# 26629          52233                                     Cliff Richards
# 28462          56075                       Northrop Grumman E-2 Hawkeye
# 29490          58357                                             Evenks
# 35306          71668  Personal Computer Memory Card International As...
# 35675          72717                                     Categorization
# 37587          77893  An Eye for an Eye: The Untold Story of Jewish ...
# 38813          80873                                         Klagenfurt
# 39420          82272                            Electromagnetic warfare
# 40137          84075                             Demetrius I of Macedon
# 59819         115919                       Saint John Plantation, Maine
# 69037         126000                       Santa Ana Pueblo, New Mexico
# 74407         131752       Benner Township, Centre County, Pennsylvania
# 74416         131761      College Township, Centre County, Pennsylvania
# 74417         131762       Curtin Township, Centre County, Pennsylvania
# 74420         131765       Haines Township, Centre County, Pennsylvania
# 74421         131766     Halfmoon Township, Centre County, Pennsylvania
# 74422         131767       Harris Township, Centre County, Pennsylvania
# 74425         131770       Howard Township, Centre County, Pennsylvania
# 84972         145234                                    A.U.M.P. Church
# 86291         148068                               The First Four Years
# 88336         151799                          T-Mobile International AG
# 91361         158816                      Right of way (disambiguation)
# 99221         177996                                              Vardø
# 99222         177997                                              Vadsø
# 99225         178001                                              Loppa
# 99226         178002                                             Hasvik
# 99228         178004                                              Måsøy
# 99229         178005                                           Nordkapp
# 99230         178006                                          Porsanger
# 99232         178008                                            Lebesby
# 99234         178010                                             Gamvik
# 99236         178012                                       Tana, Norway
# 101823        184540                                Γ-Aminobutyric acid
# 102176        185537                                  UMkhonto we Sizwe
# 102450        186406                            Toba catastrophe theory
# 103582        189396                                      Minamoto clan
# 104732        192566                         Machiavellian intelligence
# 109781        206467                              William Adams (pilot)
# 112114        213018                       Protestant Church in Germany
# 112799        214909                         Essad Toptani (politician)
# 115790        223929                                           Subpoena
# 116682        226156                                 Washington Federal
# 118184        230351                                 Muhammad Ayub Khan
# 122308        241855            Fantastic Beasts and Where to Find Them
# 123375        245342                       Galician-language literature
# 125432        251415                            Three musketeers (game)
# 125969        252955                                               Hugh
# 126490        254470                                      Santa Compaña
# 127561        258792                                 President of China
# 132068        271482                                             Swania
# 132077        271551                                 Anglia (peninsula)
# 138623        297302                                       Groat (coin)
# 142964        310315                               The Tube (TV series)
# 143284         49244                                                NaN
#
#                                                      text quality_text  \
# 1840    {{short description|Search algorithm finding t...           FA
# 5684    {{Wiktionary|Frisian|Friesian}}\n'''Frisian(s)...          NaN
# 14062   {{Short description|Stars and brown dwarfs wit...          NaN
# 16991   {{Short description|Chinese general and warlor...          NaN
# 22433   {{Short description|Early web browser (1993–19...          NaN
# 25574   {{short description|Bay on the island of Cuba}...          NaN
# 26629   {{short description|Brazilian comic book artis...          NaN
# 28462   {{Short description|Airborne early warning and...          NaN
# 29490   {{Short description|Ethnic group of North Asia...          NaN
# 35306   {{about|the industry body|the PCMCIA card form...          NaN
# 35675   {{short description|Organization of things, ob...          NaN
# 37587   {{Short description|Book by John Sack}}\n{{Inf...          NaN
# 38813   {{Lead too short|date=August 2023}}\n{{Use dmy...          NaN
# 39420   {{Short description|Combat involving electroni...          NaN
# 40137   {{Short description|King of Macedon (294–288 B...          NaN
# 59819   {{Infobox settlement\n|official_name          ...          NaN
# 69037   {{Use mdy dates|date=July 2023}}\n{{Infobox et...          NaN
# 74407   {{Infobox settlement\n|official_name = Benner ...          NaN
# 74416   {{Distinguish|Collegeville, Pennsylvania}}\n{{...          NaN
# 74417   {{Infobox settlement\n|official_name = Curtin ...          NaN
# 74420   {{Use mdy dates|date=May 2024}}\n{{Infobox set...          NaN
# 74421   {{Use mdy dates|date=May 2024}}\n{{Infobox set...          NaN
# 74422   {{Use mdy dates|date=May 2024}}\n{{Infobox set...          NaN
# 74425   {{Use mdy dates|date=May 2024}}\n{{Infobox set...          NaN
# 84972   {{short description|Methodist denomination}}\n...          NaN
# 86291   {{About|the album by Black Flag|the Little Hou...          NaN
# 88336   {{Short description|Brand of telecommunication...          NaN
# 91361   <noinclude>{{User:RMCD bot/subject notice|1=Ri...          NaN
# 99221   {{short description|Municipality in Finnmark, ...          NaN
# 99222   {{short description|Municipality in Finnmark, ...          NaN
# 99225   {{short description|Municipality in Finnmark, ...          NaN
# 99226   {{short description|Municipality in Finnmark, ...          NaN
# 99228   {{short description|Municipality in Finnmark, ...          NaN
# 99229   {{short description|Municipality in Finnmark, ...          NaN
# 99230   {{Short description|Municipality in Finnmark, ...          NaN
# 99232   {{short description|Municipality in Finnmark, ...          NaN
# 99234   {{short description|Municipality in Finnmark, ...          NaN
# 99236   {{short description|Municipality in Finnmark, ...          NaN
# 101823  {{Short description|Main inhibitory neurotrans...          NaN
# 102176  {{Short description|Armed wing of the African ...          NaN
# 102450  {{short description|Supereruption 74,000 years...          NaN
# 103582  {{Short description|Surname of Japanese imperi...          NaN
# 104732  [[File:Portrait of Niccolò Machiavelli by Sant...          NaN
# 109781  {{Short description|English navigator who trav...          NaN
# 112114  {{short description|Group of churches in Germa...          NaN
# 112799  {{Short description|Albanian diplomat (1863–19...          NaN
# 115790  {{Short description|Writ to compel testimony o...          NaN
# 116682  {{Short description|Seattle-based bank}}\n{{In...          NaN
# 118184  {{short description|2nd President of Pakistan ...          NaN
# 122308  {{short description|2001 book by J. K. Rowling...          NaN
# 123375  {{Short description|Body of literature}}\n<noi...          NaN
# 125432  {{Short description|Board game}}\n'''Three mus...          NaN
# 125969  <noinclude>{{User:RMCD bot/subject notice|1=Hu...          NaN
# 126490  {{redirect|Guestia}}\n{{No footnotes|date=Augu...          NaN
# 127561  '''President of China''' may refer to:\n* [[Pr...          NaN
# 132068  {{Short description|Peninsula in Schleswig-Hol...          NaN
# 132077  {{redirect|Angeln|the container ship|MV Angeln...          NaN
# 138623  {{short description|Archaic English, Scottish ...          NaN
# 142964  {{Short description|United Kingdom music telev...          NaN
# 143284  {{Short description|Value for unrepresentable ...          NaN
#
#         page_id_api quality_api
# 1840       77111278         NaN
# 5684       77183080         NaN
# 14062      77103076         NaN
# 16991      66114635         NaN
# 22433        352534         NaN
# 25574      77127267         NaN
# 26629             0         NaN
# 28462      68851583         NaN
# 29490      77128651         NaN
# 35306       3079579         NaN
# 35675      77124094         NaN
# 37587      77194505         NaN
# 38813      77114386         NaN
# 39420      77200534         NaN
# 40137         84149         NaN
# 59819      77124021         NaN
# 69037      77142278         NaN
# 74407      77194096         NaN
# 74416      77193951         NaN
# 74417      77202609         NaN
# 74420      77202557         NaN
# 74421      77202560         NaN
# 74422      77202550         NaN
# 74425      77202569         NaN
# 84972      77140755         NaN
# 86291      77164977         NaN
# 88336      77131691         NaN
# 91361      77142720         NaN
# 99221      77098159         NaN
# 99222      77105702         NaN
# 99225      77194113         NaN
# 99226      77192867         NaN
# 99228      77148175         NaN
# 99229      77146814         NaN
# 99230      77140153         NaN
# 99232      77127869         NaN
# 99234      77126160         NaN
# 99236      77120930         NaN
# 101823     21582987         NaN
# 102176     77112602         NaN
# 102450     77114307         NaN
# 103582     77155618         NaN
# 104732     77126478         NaN
# 109781     77136673         NaN
# 112114     77181916         NaN
# 112799     77173771         NaN
# 115790     77119762         NaN
# 116682     77139847         NaN
# 118184     77123551         NaN
# 122308     77158886         NaN
# 123375     20271884         NaN
# 125432     77118365         NaN
# 125969     16315385         NaN
# 126490     77097940         NaN
# 127561     47747524         NaN
# 132068     77153403         NaN
# 132077     77153320         NaN
# 138623     77140029         NaN
# 142964     77192019         NaN
# 143284            0         NaN

# %%
df.drop(df[df['page_id_text']!=df['page_id_api']].index, inplace=True)
df.reset_index(drop=True, inplace=True)
df
# Out:
#         page_id_text            title  \
# 0                 12        Anarchism
# 1                 39           Albedo
# 2                290                A
# 3                303          Alabama
# 4                305         Achilles
# ...              ...              ...
# 143220        311305   Intelligentsia
# 143221        311306      Boch Center
# 143222        311312     Wang Theatre
# 143223        311315  Shubert Theatre
# 143224        311318    Reginald Hill
#
#                                                      text quality_text  \
# 0       {{short description|Political philosophy and m...           GA
# 1       {{Short description|Ratio of how much light is...          NaN
# 2       {{Short description|First letter of the Latin ...          NaN
# 3       {{Short description|U.S. state}}\n{{about|the ...          NaN
# 4       {{short description|Greek mythological hero}}\...          NaN
# ...                                                   ...          ...
# 143220  {{short description|Status class of university...          NaN
# 143221  {{Infobox venue\n| name                   = Th...          NaN
# 143222  {{Short description|Theater in Boston, Massach...          NaN
# 143223  '''Shubert Theatre''' or '''Shubert Theater'''...          NaN
# 143224  {{Short description|British crime writer}}\n{{...          NaN
#
#         page_id_api quality_api
# 0                12          GA
# 1                39         NaN
# 2               290           C
# 3               303           B
# 4               305           C
# ...             ...         ...
# 143220       311305         NaN
# 143221       311306         NaN
# 143222       311312         NaN
# 143223       311315         NaN
# 143224       311318         NaN
#
# [143225 rows x 6 columns]

# %% [markdown]
# - 'quality_api' is classified as FA, but not for 'quality_text'

# %%
df[(df['quality_api']=='FA') & (df['quality_text']!='FA')]
# Out:
# Empty DataFrame
# Columns: [page_id_text, title, text, quality_text, page_id_api, quality_api]
# Index: []

# %% [markdown]
# - 'quality_api' is classified as GA, but not for 'quality_text'
# - it is meant to be GA

# %%
df[(df['quality_api']=='GA') & (df['quality_text']!='GA')]
# Out:
#        page_id_text           title  \
# 85760        146929  George Pickett
#
#                                                     text quality_text  \
# 85760  {{Short description|Confederate army general (...          NaN
#
#        page_id_api quality_api
# 85760       146929          GA

# %%
df['quality_text'][85760] = 'GA'
# Out:
# <ipython-input-8-aab6331a9ef2>:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df['quality_text'][85760] = 'GA'

# %%
df.iloc[85760]
# Out:
# page_id_text                                               146929
# title                                              George Pickett
# text            {{Short description|Confederate army general (...
# quality_text                                                   GA
# page_id_api                                                146929
# quality_api                                                    GA
# Name: 85760, dtype: object

# %% [markdown]
# - 'quality_text' is classifed as GA, but not for 'quality_api'
# - they are meant to be A

# %%
df[(df['quality_text']=='GA') & (df['quality_api']!='GA') & (~df['quality_api'].isnull())]
# Out:
#         page_id_text                            title  \
# 24666          47968                Battle of Salamis
# 90970         157957  Battle of the Plains of Abraham
# 92326         161350                  Hugh John Casey
# 106888        198447           Arrow (missile family)
# 110982        209815                      HMS Belfast
#
#                                                      text quality_text  \
# 24666   {{Short description|480 BC naval battle of the...           GA
# 90970   {{Short description|1759 battle between Britis...           GA
# 92326   {{Short description|United States Army General...           GA
# 106888  {{Use mdy dates|date=November 2023}}\n{{Short ...           GA
# 110982  {{Short description|British light cruiser}}\n{...           GA
#
#         page_id_api quality_api
# 24666         47968           A
# 90970        157957           A
# 92326        161350           A
# 106888       198447           A
# 110982       209815           A

# %% [markdown]
# - 'quality_text' is classifed as FA, but not for 'quality_api'

# %%
df[(df['quality_text']=='FA') & (df['quality_api']!='FA') & (~df['quality_api'].isnull())]
# Out:
# Empty DataFrame
# Columns: [page_id_text, title, text, quality_text, page_id_api, quality_api]
# Index: []

# %% [markdown]
# - 'quality_text' is classifed as GA, but 'quality_api' is null

# %%
df[(df['quality_text']=='GA') & (df['quality_api'].isnull())]
# Out:
#         page_id_text                       title  \
# 5                307             Abraham Lincoln
# 6                308                   Aristotle
# 14               339                    Ayn Rand
# 37               627                 Agriculture
# 59               666                Alkali metal
# ...              ...                         ...
# 142940        310414                  Art Farmer
# 143104        310898                       Croup
# 143107        310912                    Bat'leth
# 143109        310917                  Starflight
# 143178        311178  St Pancras railway station
#
#                                                      text quality_text  \
# 5       {{Short description|President of the United St...           GA
# 6       {{Short description|Ancient Greek philosopher ...           GA
# 14      {{Short description|Russian-born American auth...           GA
# 37      {{short description|Cultivation of plants and ...           GA
# 59      {{short description|Group of highly reactive c...           GA
# ...                                                   ...          ...
# 142940  {{Short description|American jazz trumpeter (1...           GA
# 143104  {{Short description|Respiratory infection ofte...           GA
# 143107  {{short description|Star Trek weapon}}\n{{Use ...           GA
# 143109  {{Short description|1986 video game}}\n{{About...           GA
# 143178  {{short description|Railway terminus in centra...           GA
#
#         page_id_api quality_api
# 5               307         NaN
# 6               308         NaN
# 14              339         NaN
# 37              627         NaN
# 59              666         NaN
# ...             ...         ...
# 142940       310414         NaN
# 143104       310898         NaN
# 143107       310912         NaN
# 143109       310917         NaN
# 143178       311178         NaN
#
# [2778 rows x 6 columns]

# %% [markdown]
# - 'quality_text' is classifed as FA, but 'quality_api' is null

# %%
df[(df['quality_text']=='FA') & (df['quality_api'].isnull())]
# Out:
#         page_id_text                   title  \
# 35               621               Amphibian
# 55               662               Apollo 11
# 56               663                Apollo 8
# 119              798   Aries (constellation)
# 148              874           Ancient Egypt
# ...              ...                     ...
# 142487        309106  Disco Demolition Night
# 142748        309803         Remain in Light
# 142865        310171        Harmon Killebrew
# 143170        311144         Margaret Fuller
# 143202        311236              Water rail
#
#                                                      text quality_text  \
# 35      {{Short description|Class of ectothermic tetra...           FA
# 55      {{Short description|First crewed Moon landing ...           FA
# 56      {{Short description|First crewed space mission...           FA
# 119     {{Short description|Zodiac constellation in th...           FA
# 148     {{Short description|Northeastern African civil...           FA
# ...                                                   ...          ...
# 142487  {{Use mdy dates|date=April 2023}}\n{{Short des...           FA
# 142748  {{Use mdy dates|date=April 2017}}\n{{Infobox a...           FA
# 142865  {{short description|American baseball player (...           FA
# 143170  {{short description|American writer and women'...           FA
# 143202  {{short description|Species of bird}}\n{{Speci...           FA
#
#         page_id_api quality_api
# 35              621         NaN
# 55              662         NaN
# 56              663         NaN
# 119             798         NaN
# 148             874         NaN
# ...             ...         ...
# 142487       309106         NaN
# 142748       309803         NaN
# 142865       310171         NaN
# 143170       311144         NaN
# 143202       311236         NaN
#
# [1159 rows x 6 columns]

# %%
df
# Out:
#         page_id_text            title  \
# 0                 12        Anarchism
# 1                 39           Albedo
# 2                290                A
# 3                303          Alabama
# 4                305         Achilles
# ...              ...              ...
# 143220        311305   Intelligentsia
# 143221        311306      Boch Center
# 143222        311312     Wang Theatre
# 143223        311315  Shubert Theatre
# 143224        311318    Reginald Hill
#
#                                                      text quality_text  \
# 0       {{short description|Political philosophy and m...           GA
# 1       {{Short description|Ratio of how much light is...          NaN
# 2       {{Short description|First letter of the Latin ...          NaN
# 3       {{Short description|U.S. state}}\n{{about|the ...          NaN
# 4       {{short description|Greek mythological hero}}\...          NaN
# ...                                                   ...          ...
# 143220  {{short description|Status class of university...          NaN
# 143221  {{Infobox venue\n| name                   = Th...          NaN
# 143222  {{Short description|Theater in Boston, Massach...          NaN
# 143223  '''Shubert Theatre''' or '''Shubert Theater'''...          NaN
# 143224  {{Short description|British crime writer}}\n{{...          NaN
#
#         page_id_api quality_api
# 0                12          GA
# 1                39         NaN
# 2               290           C
# 3               303           B
# 4               305           C
# ...             ...         ...
# 143220       311305         NaN
# 143221       311306         NaN
# 143222       311312         NaN
# 143223       311315         NaN
# 143224       311318         NaN
#
# [143225 rows x 6 columns]

# %%
df['quality_api'].value_counts()
# Out:
# quality_api
# Start       8607
# C           3639
# B           1859
# Stub        1187
# List         696
# Disambig     585
# GA           364
# FA           152
# File          40
# SIA           31
# Redirect      17
# FL            17
# Project       11
# A              7
# start          6
# Portal         3
# CL             3
# BL             2
# Draft          1
# Name: count, dtype: int64

# %%
df['quality_text'].value_counts()
# Out:
# quality_text
# GA    3147
# FA    1311
# Name: count, dtype: int64

# %% [markdown]
# - FA 1300
# - GA 1300
# - reliable: 2600
#
#
# - B 650
# - C 650
# - Start 650
# - Stub 650
# - non-reliable: 2600

# %%
df[df['quality_api']=='C']
# Out:
#         page_id_text                          title  \
# 2                290                              A
# 4                305                       Achilles
# 29               597        Austroasiatic languages
# 30               599          Afroasiatic languages
# 65               677                      Ambiguity
# ...              ...                            ...
# 143182        311188       John Lucas (philosopher)
# 143184        311193                  Memory paging
# 143211        311264  American Humanist Association
# 143213        311272            Treaty of Alcáçovas
# 143215        311282                        Gunship
#
#                                                      text quality_text  \
# 2       {{Short description|First letter of the Latin ...          NaN
# 4       {{short description|Greek mythological hero}}\...          NaN
# 29      {{Short description|Language family concentrat...          NaN
# 30      {{short description|Large language family of A...          NaN
# 65      {{Short description|Type of uncertainty of mea...          NaN
# ...                                                   ...          ...
# 143182  {{Short description|British philosopher (1929–...          NaN
# 143184  {{Short description|Computer memory management...          NaN
# 143211  {{short description|US secularist advocacy org...          NaN
# 143213  {{Short description|1479 treaty between Spain ...          NaN
# 143215  {{Short description|Type of military aircraft}...          NaN
#
#         page_id_api quality_api
# 2               290           C
# 4               305           C
# 29              597           C
# 30              599           C
# 65              677           C
# ...             ...         ...
# 143182       311188           C
# 143184       311193           C
# 143211       311264           C
# 143213       311272           C
# 143215       311282           C
#
# [3639 rows x 6 columns]

# %% [markdown]
# ### preprocessing

# %%
df2 = df.copy()
df2
# Out:
#         page_id_text            title  \
# 0                 12        Anarchism
# 1                 39           Albedo
# 2                290                A
# 3                303          Alabama
# 4                305         Achilles
# ...              ...              ...
# 143220        311305   Intelligentsia
# 143221        311306      Boch Center
# 143222        311312     Wang Theatre
# 143223        311315  Shubert Theatre
# 143224        311318    Reginald Hill
#
#                                                      text quality_text  \
# 0       {{short description|Political philosophy and m...           GA
# 1       {{Short description|Ratio of how much light is...          NaN
# 2       {{Short description|First letter of the Latin ...          NaN
# 3       {{Short description|U.S. state}}\n{{about|the ...          NaN
# 4       {{short description|Greek mythological hero}}\...          NaN
# ...                                                   ...          ...
# 143220  {{short description|Status class of university...          NaN
# 143221  {{Infobox venue\n| name                   = Th...          NaN
# 143222  {{Short description|Theater in Boston, Massach...          NaN
# 143223  '''Shubert Theatre''' or '''Shubert Theater'''...          NaN
# 143224  {{Short description|British crime writer}}\n{{...          NaN
#
#         page_id_api quality_api
# 0                12          GA
# 1                39         NaN
# 2               290           C
# 3               303           B
# 4               305           C
# ...             ...         ...
# 143220       311305         NaN
# 143221       311306         NaN
# 143222       311312         NaN
# 143223       311315         NaN
# 143224       311318         NaN
#
# [143225 rows x 6 columns]

# %%
df2.drop(['page_id_api'], axis=1, inplace=True)

# %%
df2
# Out:
#         page_id_text            title  \
# 0                 12        Anarchism
# 1                 39           Albedo
# 2                290                A
# 3                303          Alabama
# 4                305         Achilles
# ...              ...              ...
# 143220        311305   Intelligentsia
# 143221        311306      Boch Center
# 143222        311312     Wang Theatre
# 143223        311315  Shubert Theatre
# 143224        311318    Reginald Hill
#
#                                                      text quality_text  \
# 0       {{short description|Political philosophy and m...           GA
# 1       {{Short description|Ratio of how much light is...          NaN
# 2       {{Short description|First letter of the Latin ...          NaN
# 3       {{Short description|U.S. state}}\n{{about|the ...          NaN
# 4       {{short description|Greek mythological hero}}\...          NaN
# ...                                                   ...          ...
# 143220  {{short description|Status class of university...          NaN
# 143221  {{Infobox venue\n| name                   = Th...          NaN
# 143222  {{Short description|Theater in Boston, Massach...          NaN
# 143223  '''Shubert Theatre''' or '''Shubert Theater'''...          NaN
# 143224  {{Short description|British crime writer}}\n{{...          NaN
#
#        quality_api
# 0               GA
# 1              NaN
# 2                C
# 3                B
# 4                C
# ...            ...
# 143220         NaN
# 143221         NaN
# 143222         NaN
# 143223         NaN
# 143224         NaN
#
# [143225 rows x 5 columns]

# %%
df2.rename(columns={'page_id_text': 'page_id'}, inplace=True)

# %%
df2
# Out:
#         page_id            title  \
# 0            12        Anarchism
# 1            39           Albedo
# 2           290                A
# 3           303          Alabama
# 4           305         Achilles
# ...         ...              ...
# 143220   311305   Intelligentsia
# 143221   311306      Boch Center
# 143222   311312     Wang Theatre
# 143223   311315  Shubert Theatre
# 143224   311318    Reginald Hill
#
#                                                      text quality_text  \
# 0       {{short description|Political philosophy and m...           GA
# 1       {{Short description|Ratio of how much light is...          NaN
# 2       {{Short description|First letter of the Latin ...          NaN
# 3       {{Short description|U.S. state}}\n{{about|the ...          NaN
# 4       {{short description|Greek mythological hero}}\...          NaN
# ...                                                   ...          ...
# 143220  {{short description|Status class of university...          NaN
# 143221  {{Infobox venue\n| name                   = Th...          NaN
# 143222  {{Short description|Theater in Boston, Massach...          NaN
# 143223  '''Shubert Theatre''' or '''Shubert Theater'''...          NaN
# 143224  {{Short description|British crime writer}}\n{{...          NaN
#
#        quality_api
# 0               GA
# 1              NaN
# 2                C
# 3                B
# 4                C
# ...            ...
# 143220         NaN
# 143221         NaN
# 143222         NaN
# 143223         NaN
# 143224         NaN
#
# [143225 rows x 5 columns]

# %% [markdown]
# 1. FA dataset

# %%
FA = df2[df2['quality_text']=='FA']
FA
# Out:
#         page_id                  title  \
# 35          621              Amphibian
# 55          662              Apollo 11
# 56          663               Apollo 8
# 119         798  Aries (constellation)
# 148         874          Ancient Egypt
# ...         ...                    ...
# 142499   309142       Irakli Tsereteli
# 142748   309803        Remain in Light
# 142865   310171       Harmon Killebrew
# 143170   311144        Margaret Fuller
# 143202   311236             Water rail
#
#                                                      text quality_text  \
# 35      {{Short description|Class of ectothermic tetra...           FA
# 55      {{Short description|First crewed Moon landing ...           FA
# 56      {{Short description|First crewed space mission...           FA
# 119     {{Short description|Zodiac constellation in th...           FA
# 148     {{Short description|Northeastern African civil...           FA
# ...                                                   ...          ...
# 142499  {{short description|Georgian politician (1881–...           FA
# 142748  {{Use mdy dates|date=April 2017}}\n{{Infobox a...           FA
# 142865  {{short description|American baseball player (...           FA
# 143170  {{short description|American writer and women'...           FA
# 143202  {{short description|Species of bird}}\n{{Speci...           FA
#
#        quality_api
# 35             NaN
# 55             NaN
# 56             NaN
# 119            NaN
# 148            NaN
# ...            ...
# 142499          FA
# 142748         NaN
# 142865         NaN
# 143170         NaN
# 143202         NaN
#
# [1311 rows x 5 columns]

# %%
FA2 = FA.sample(n=1300)
FA2
# Out:
#         page_id                            title  \
# 137096   293253     Princess Alice of Battenberg
# 130870   266376              Benedetto Pistrucci
# 71006    128158                Macintosh Classic
# 11275     22790                      Ozzie Smith
# 22502     43455                     Tang dynasty
# ...         ...                              ...
# 9706      19694                 Mercury (planet)
# 9888      20069                  Morihei Ueshiba
# 101471   183655                    HMS Endeavour
# 49755    103990  Holkham National Nature Reserve
# 93520    164381   ...And Justice for All (album)
#
#                                                      text quality_text  \
# 137096  {{short description|Princess Andrew of Greece ...           FA
# 130870  {{short description|Italian engraver (1783–185...           FA
# 71006   {{Short description|Personal computer by Apple...           FA
# 11275   {{Short description|American professional base...           FA
# 22502   {{pp-protected|small=yes}}\n{{Short descriptio...           FA
# ...                                                   ...          ...
# 9706    {{Short description|First planet from the Sun}...           FA
# 9888    {{short description|20th-century Japanese mart...           FA
# 101471  {{short description|18th-century Royal Navy re...           FA
# 49755   {{short description|Nature reserve in the Unit...           FA
# 93520   {{featured article}}\n{{Use mdy dates|date=Sep...           FA
#
#        quality_api
# 137096          FA
# 130870         NaN
# 71006           FA
# 11275          NaN
# 22502          NaN
# ...            ...
# 9706           NaN
# 9888           NaN
# 101471         NaN
# 49755           FA
# 93520          NaN
#
# [1300 rows x 5 columns]

# %%
FA2.drop(['quality_api'], axis=1, inplace=True)
FA2.rename(columns={'quality_text': 'quality'}, inplace=True)

# %%
FA2
# Out:
#         page_id                            title  \
# 137096   293253     Princess Alice of Battenberg
# 130870   266376              Benedetto Pistrucci
# 71006    128158                Macintosh Classic
# 11275     22790                      Ozzie Smith
# 22502     43455                     Tang dynasty
# ...         ...                              ...
# 9706      19694                 Mercury (planet)
# 9888      20069                  Morihei Ueshiba
# 101471   183655                    HMS Endeavour
# 49755    103990  Holkham National Nature Reserve
# 93520    164381   ...And Justice for All (album)
#
#                                                      text quality
# 137096  {{short description|Princess Andrew of Greece ...      FA
# 130870  {{short description|Italian engraver (1783–185...      FA
# 71006   {{Short description|Personal computer by Apple...      FA
# 11275   {{Short description|American professional base...      FA
# 22502   {{pp-protected|small=yes}}\n{{Short descriptio...      FA
# ...                                                   ...     ...
# 9706    {{Short description|First planet from the Sun}...      FA
# 9888    {{short description|20th-century Japanese mart...      FA
# 101471  {{short description|18th-century Royal Navy re...      FA
# 49755   {{short description|Nature reserve in the Unit...      FA
# 93520   {{featured article}}\n{{Use mdy dates|date=Sep...      FA
#
# [1300 rows x 4 columns]

# %% [markdown]
# 2. GA dataset

# %%
GA = df2[df2['quality_text']=='GA']
GA
# Out:
#         page_id                       title  \
# 0            12                   Anarchism
# 5           307             Abraham Lincoln
# 6           308                   Aristotle
# 14          339                    Ayn Rand
# 37          627                 Agriculture
# ...         ...                         ...
# 142940   310414                  Art Farmer
# 143104   310898                       Croup
# 143107   310912                    Bat'leth
# 143109   310917                  Starflight
# 143178   311178  St Pancras railway station
#
#                                                      text quality_text  \
# 0       {{short description|Political philosophy and m...           GA
# 5       {{Short description|President of the United St...           GA
# 6       {{Short description|Ancient Greek philosopher ...           GA
# 14      {{Short description|Russian-born American auth...           GA
# 37      {{short description|Cultivation of plants and ...           GA
# ...                                                   ...          ...
# 142940  {{Short description|American jazz trumpeter (1...           GA
# 143104  {{Short description|Respiratory infection ofte...           GA
# 143107  {{short description|Star Trek weapon}}\n{{Use ...           GA
# 143109  {{Short description|1986 video game}}\n{{About...           GA
# 143178  {{short description|Railway terminus in centra...           GA
#
#        quality_api
# 0               GA
# 5              NaN
# 6              NaN
# 14             NaN
# 37             NaN
# ...            ...
# 142940         NaN
# 143104         NaN
# 143107         NaN
# 143109         NaN
# 143178         NaN
#
# [3147 rows x 5 columns]

# %%
GA2 = GA.sample(n=1300)
GA2
# Out:
#         page_id                    title  \
# 40234     84317              Ansel Adams
# 140334   302789             Vic Fontaine
# 136756   292161              Radar Scope
# 6951      14348             Homo habilis
# 106745   197948  USS Mississippi (BB-41)
# ...         ...                      ...
# 23442     45220      Staines-upon-Thames
# 83816    142651              John Ogilby
# 47505     98648                The Byrds
# 35868     73231      Weather forecasting
# 21447     41545        Avogadro constant
#
#                                                      text quality_text  \
# 40234   {{Short description|American photographer and ...           GA
# 140334  {{Short description|Fictional character from T...           GA
# 136756  {{good article}}\n{{short description|1980 sho...           GA
# 6951    {{short description|Archaic human species from...           GA
# 106745  {{Short description|Dreadnought battleship of ...           GA
# ...                                                   ...          ...
# 23442   {{Short description|Town in Surrey, England}}\...           GA
# 83816   {{good article}}\n{{Short description|Scottish...           GA
# 47505   {{short description|American rock band}}\n{{di...           GA
# 35868   {{Short description|Science and technology app...           GA
# 21447   {{Short description|Fundamental metric system ...           GA
#
#        quality_api
# 40234          NaN
# 140334          GA
# 136756          GA
# 6951           NaN
# 106745         NaN
# ...            ...
# 23442           GA
# 83816          NaN
# 47505          NaN
# 35868          NaN
# 21447          NaN
#
# [1300 rows x 5 columns]

# %%
GA2.drop(['quality_api'], axis=1, inplace=True)
GA2.rename(columns={'quality_text': 'quality'}, inplace=True)

# %%
GA2
# Out:
#         page_id                    title  \
# 40234     84317              Ansel Adams
# 140334   302789             Vic Fontaine
# 136756   292161              Radar Scope
# 6951      14348             Homo habilis
# 106745   197948  USS Mississippi (BB-41)
# ...         ...                      ...
# 23442     45220      Staines-upon-Thames
# 83816    142651              John Ogilby
# 47505     98648                The Byrds
# 35868     73231      Weather forecasting
# 21447     41545        Avogadro constant
#
#                                                      text quality
# 40234   {{Short description|American photographer and ...      GA
# 140334  {{Short description|Fictional character from T...      GA
# 136756  {{good article}}\n{{short description|1980 sho...      GA
# 6951    {{short description|Archaic human species from...      GA
# 106745  {{Short description|Dreadnought battleship of ...      GA
# ...                                                   ...     ...
# 23442   {{Short description|Town in Surrey, England}}\...      GA
# 83816   {{good article}}\n{{Short description|Scottish...      GA
# 47505   {{short description|American rock band}}\n{{di...      GA
# 35868   {{Short description|Science and technology app...      GA
# 21447   {{Short description|Fundamental metric system ...      GA
#
# [1300 rows x 4 columns]

# %% [markdown]
# 3. B dataset

# %%
B = df2[df2['quality_api']=='B']
B
# Out:
#         page_id                       title  \
# 3           303                     Alabama
# 31          600                     Andorra
# 102         771  American Revolutionary War
# 138         852       Alexander Graham Bell
# 250        1088    Azerbaijani Armed Forces
# ...         ...                         ...
# 142944   310435                Arad, Israel
# 142946   310437            Pictish language
# 142999   310599           Fitness landscape
# 143004   310619                    Achewood
# 143059   310780            Eurocopter Tiger
#
#                                                      text quality_text  \
# 3       {{Short description|U.S. state}}\n{{about|the ...          NaN
# 31      {{short description|Country in Western Europe}...          NaN
# 102     {{Short description|1775–1783 American war of ...          NaN
# 138     {{short description|Inventor who patented the ...          NaN
# 250     {{Short description|Military forces of Azerbai...          NaN
# ...                                                   ...          ...
# 142944  {{for multi|the archaeological site|Tel Arad|o...          NaN
# 142946  {{Short description|Extinct language spoken by...          NaN
# 142999  {{Short description|Model used to visualise re...          NaN
# 143004  {{short description|Webcomic by Chris Onstad}}...          NaN
# 143059  {{Short description|European attack helicopter...          NaN
#
#        quality_api
# 3                B
# 31               B
# 102              B
# 138              B
# 250              B
# ...            ...
# 142944           B
# 142946           B
# 142999           B
# 143004           B
# 143059           B
#
# [1859 rows x 5 columns]

# %%
B2 = B.sample(n=650)
B2
# Out:
#         page_id                title  \
# 33849     68145      The Jazz Singer
# 96532    171885          Family farm
# 123687   246429              Beothuk
# 39482     82465     Gordon Lightfoot
# 111263   210568  Joe Hill (activist)
# ...         ...                  ...
# 31639     62432        Pawnee people
# 80036    137679   Victoria, Virginia
# 113366   216611       Let's Get Free
# 15169     30450    Topological space
# 13132     26341        Radioteletype
#
#                                                      text quality_text  \
# 33849   {{Short description|1927 film by Alan Crosland...          NaN
# 96532   {{Short description|Farm owned or operated by ...          NaN
# 123687  {{Short description|Historical Indigenous peop...          NaN
# 39482   {{Short description|Canadian singer-songwriter...          NaN
# 111263  {{short description|Swedish-American labor act...          NaN
# ...                                                   ...          ...
# 31639   {{Short description|Indigenous people of the G...          NaN
# 80036   {{Use mdy dates|date=May 2024}}\n{{Infobox set...          NaN
# 113366  {{Infobox album|\n| name       = Let's Get Fre...          NaN
# 15169   {{Short description|Mathematical space with a ...          NaN
# 13132   {{Short description|Radio linked electromechan...          NaN
#
#        quality_api
# 33849            B
# 96532            B
# 123687           B
# 39482            B
# 111263           B
# ...            ...
# 31639            B
# 80036            B
# 113366           B
# 15169            B
# 13132            B
#
# [650 rows x 5 columns]

# %%
B2.drop(['quality_text'], axis=1, inplace=True)
B2.rename(columns={'quality_api': 'quality'}, inplace=True)

# %%
B2
# Out:
#         page_id                title  \
# 33849     68145      The Jazz Singer
# 96532    171885          Family farm
# 123687   246429              Beothuk
# 39482     82465     Gordon Lightfoot
# 111263   210568  Joe Hill (activist)
# ...         ...                  ...
# 31639     62432        Pawnee people
# 80036    137679   Victoria, Virginia
# 113366   216611       Let's Get Free
# 15169     30450    Topological space
# 13132     26341        Radioteletype
#
#                                                      text quality
# 33849   {{Short description|1927 film by Alan Crosland...       B
# 96532   {{Short description|Farm owned or operated by ...       B
# 123687  {{Short description|Historical Indigenous peop...       B
# 39482   {{Short description|Canadian singer-songwriter...       B
# 111263  {{short description|Swedish-American labor act...       B
# ...                                                   ...     ...
# 31639   {{Short description|Indigenous people of the G...       B
# 80036   {{Use mdy dates|date=May 2024}}\n{{Infobox set...       B
# 113366  {{Infobox album|\n| name       = Let's Get Fre...       B
# 15169   {{Short description|Mathematical space with a ...       B
# 13132   {{Short description|Radio linked electromechan...       B
#
# [650 rows x 4 columns]

# %% [markdown]
# 4. C dataset

# %%
C = df2[df2['quality_api']=='C']
C
# Out:
#         page_id                          title  \
# 2           290                              A
# 4           305                       Achilles
# 29          597        Austroasiatic languages
# 30          599          Afroasiatic languages
# 65          677                      Ambiguity
# ...         ...                            ...
# 143182   311188       John Lucas (philosopher)
# 143184   311193                  Memory paging
# 143211   311264  American Humanist Association
# 143213   311272            Treaty of Alcáçovas
# 143215   311282                        Gunship
#
#                                                      text quality_text  \
# 2       {{Short description|First letter of the Latin ...          NaN
# 4       {{short description|Greek mythological hero}}\...          NaN
# 29      {{Short description|Language family concentrat...          NaN
# 30      {{short description|Large language family of A...          NaN
# 65      {{Short description|Type of uncertainty of mea...          NaN
# ...                                                   ...          ...
# 143182  {{Short description|British philosopher (1929–...          NaN
# 143184  {{Short description|Computer memory management...          NaN
# 143211  {{short description|US secularist advocacy org...          NaN
# 143213  {{Short description|1479 treaty between Spain ...          NaN
# 143215  {{Short description|Type of military aircraft}...          NaN
#
#        quality_api
# 2                C
# 4                C
# 29               C
# 30               C
# 65               C
# ...            ...
# 143182           C
# 143184           C
# 143211           C
# 143213           C
# 143215           C
#
# [3639 rows x 5 columns]

# %%
C2 = C.sample(n=650)
C2
# Out:
#         page_id                   title  \
# 129826   263154           Dermot Morgan
# 112785   214993            Macropodidae
# 123398   245600                 Cao Zhi
# 14277     28577  Skuld (Oh My Goddess!)
# 15734     31542             Twin cities
# ...         ...                     ...
# 108162   201929    Lieutenant commander
# 36371     74635        Probus (emperor)
# 9816      19935              Mimeograph
# 13050     26191                 Red Sea
# 70277    127350       Oakdale, New York
#
#                                                      text quality_text  \
# 129826  {{Short description|Irish comedian and actor (...          NaN
# 112785  {{Short description|Family of marsupial mammal...          NaN
# 123398  {{Short description|State of Cao Wei prince an...          NaN
# 14277   {{DISPLAYTITLE:Skuld (''Oh My Goddess!'')}}\n{...          NaN
# 15734   {{Short description|Neighboring cities that be...          NaN
# ...                                                   ...          ...
# 108162  {{Short description|Commissioned officer rank}...          NaN
# 36371   {{short description|Roman emperor from 276 to ...          NaN
# 9816    {{short description|Type of duplicating machin...          NaN
# 13050   {{Short description|Arm of the Indian Ocean be...          NaN
# 70277   {{Use mdy dates|date=July 2023}}\n{{Infobox se...          NaN
#
#        quality_api
# 129826           C
# 112785           C
# 123398           C
# 14277            C
# 15734            C
# ...            ...
# 108162           C
# 36371            C
# 9816             C
# 13050            C
# 70277            C
#
# [650 rows x 5 columns]

# %%
C2.drop(['quality_text'], axis=1, inplace=True)
C2.rename(columns={'quality_api': 'quality'}, inplace=True)

# %%
C2
# Out:
#         page_id                   title  \
# 129826   263154           Dermot Morgan
# 112785   214993            Macropodidae
# 123398   245600                 Cao Zhi
# 14277     28577  Skuld (Oh My Goddess!)
# 15734     31542             Twin cities
# ...         ...                     ...
# 108162   201929    Lieutenant commander
# 36371     74635        Probus (emperor)
# 9816      19935              Mimeograph
# 13050     26191                 Red Sea
# 70277    127350       Oakdale, New York
#
#                                                      text quality
# 129826  {{Short description|Irish comedian and actor (...       C
# 112785  {{Short description|Family of marsupial mammal...       C
# 123398  {{Short description|State of Cao Wei prince an...       C
# 14277   {{DISPLAYTITLE:Skuld (''Oh My Goddess!'')}}\n{...       C
# 15734   {{Short description|Neighboring cities that be...       C
# ...                                                   ...     ...
# 108162  {{Short description|Commissioned officer rank}...       C
# 36371   {{short description|Roman emperor from 276 to ...       C
# 9816    {{short description|Type of duplicating machin...       C
# 13050   {{Short description|Arm of the Indian Ocean be...       C
# 70277   {{Use mdy dates|date=July 2023}}\n{{Infobox se...       C
#
# [650 rows x 4 columns]

# %% [markdown]
# 5. Start dataset

# %%
Start = df2[df2['quality_api']=='Start']
Start
# Out:
#         page_id                       title  \
# 101         766              Abstract (law)
# 179         925           Asociación Alumni
# 181         929                       Alpha
# 209        1005                      August
# 251        1091        Geography of Armenia
# ...         ...                         ...
# 143149   311092                  Paul Kurtz
# 143150   311094            Ex parte Garland
# 143151   311098                Edith Bunker
# 143181   311182  Berzelius (secret society)
# 143183   311192                Air Georgian
#
#                                                      text quality_text  \
# 101     {{short description|Summary of a legal documen...          NaN
# 179     {{About|the rugby union team|the defunct footb...          NaN
# 181     {{short description|First letter of the Greek ...          NaN
# 209     {{short description|Eighth month in the Julian...          NaN
# 251     {{Short description|Overview of the geography ...          NaN
# ...                                                   ...          ...
# 143149  {{Use mdy dates|date=April 2022}}\n{{Short des...          NaN
# 143150  {{Use mdy dates|date=September 2023}}\n{{Infob...          NaN
# 143151  {{Short description|Fictional character}}\n{{I...          NaN
# 143181  {{Short description|Secret society at Yale Uni...          NaN
# 143183  {{short description|Defunct Canadian airline}}...          NaN
#
#        quality_api
# 101          Start
# 179          Start
# 181          Start
# 209          Start
# 251          Start
# ...            ...
# 143149       Start
# 143150       Start
# 143151       Start
# 143181       Start
# 143183       Start
#
# [8607 rows x 5 columns]

# %%
Start2 = Start.sample(n=650)
Start2
# Out:
#         page_id                            title  \
# 74887    132265  Woodcock Township, Pennsylvania
# 100458   180803               The Krypton Factor
# 59332    115439            Morganfield, Kentucky
# 128300   260094        Smithtown (CDP), New York
# 37449     77647               Wake Island (film)
# ...         ...                              ...
# 133573   277206                      Freethought
# 55809    111395                Momence, Illinois
# 8252      16897                           Knight
# 55764    111349            Apple River, Illinois
# 114444   219797                  Lake Washington
#
#                                                      text quality_text  \
# 74887   {{Infobox settlement\n| name                  ...          NaN
# 100458  {{Short description|British television game sh...          NaN
# 59332   {{redirect|Morganfield|the surname|Morganfield...          NaN
# 128300  {{Use mdy dates|date=May 2023}}\n{{Infobox set...          NaN
# 37449   {{short description|1942 film directed by John...          NaN
# ...                                                   ...          ...
# 133573  {{Distinguish|freedom of thought|free will}}\n...          NaN
# 55809   {{Use mdy dates|date=July 2023}}\n{{Infobox se...          NaN
# 8252    {{short description|Honorary title awarded for...          NaN
# 55764   {{about|the village|the nearby river of the sa...          NaN
# 114444  {{Other uses}}\n{{short description|Freshwater...          NaN
#
#        quality_api
# 74887        Start
# 100458       Start
# 59332        Start
# 128300       Start
# 37449        Start
# ...            ...
# 133573       Start
# 55809        Start
# 8252         Start
# 55764        Start
# 114444       Start
#
# [650 rows x 5 columns]

# %%
Start2.drop(['quality_text'], axis=1, inplace=True)
Start2.rename(columns={'quality_api': 'quality'}, inplace=True)

# %%
Start2
# Out:
#         page_id                            title  \
# 74887    132265  Woodcock Township, Pennsylvania
# 100458   180803               The Krypton Factor
# 59332    115439            Morganfield, Kentucky
# 128300   260094        Smithtown (CDP), New York
# 37449     77647               Wake Island (film)
# ...         ...                              ...
# 133573   277206                      Freethought
# 55809    111395                Momence, Illinois
# 8252      16897                           Knight
# 55764    111349            Apple River, Illinois
# 114444   219797                  Lake Washington
#
#                                                      text quality
# 74887   {{Infobox settlement\n| name                  ...   Start
# 100458  {{Short description|British television game sh...   Start
# 59332   {{redirect|Morganfield|the surname|Morganfield...   Start
# 128300  {{Use mdy dates|date=May 2023}}\n{{Infobox set...   Start
# 37449   {{short description|1942 film directed by John...   Start
# ...                                                   ...     ...
# 133573  {{Distinguish|freedom of thought|free will}}\n...   Start
# 55809   {{Use mdy dates|date=July 2023}}\n{{Infobox se...   Start
# 8252    {{short description|Honorary title awarded for...   Start
# 55764   {{about|the village|the nearby river of the sa...   Start
# 114444  {{Other uses}}\n{{short description|Freshwater...   Start
#
# [650 rows x 4 columns]

# %% [markdown]
# 6. Stub dataset

# %%
Stub = df2[df2['quality_api']=='Stub']
Stub
# Out:
#         page_id                               title  \
# 815        2093                           Abimelech
# 1548       3681  Telecommunications in Burkina Faso
# 1793       4178                       Bill Schelter
# 3620       7755                               Cluny
# 3666       7838                    Compound turbine
# ...         ...                                 ...
# 143002   310612                            Drive-in
# 143028   310684                         Henry Raspe
# 143030   310689                    Maryland, London
# 143120   310956                       Soong Ai-ling
# 143214   311279                     Nueil-sous-Faye
#
#                                                      text quality_text  \
# 815     {{Short description|Name given to Philistine k...          NaN
# 1548    '''Telecommunications in Burkina Faso''' inclu...          NaN
# 1793    {{Short description|American mathematician and...          NaN
# 3620    {{Other uses}}\n{{Infobox French commune\n|nam...          NaN
# 3666    {{Short description|Type of steam turbine}}\n{...          NaN
# ...                                                   ...          ...
# 143002  {{other uses|Drive-in (disambiguation)}}\n[[Fi...          NaN
# 143028  {{Short description|German nobleman and throne...          NaN
# 143030  {{Short description|Area in East London, Engla...          NaN
# 143120  {{Short description|Chinese businesswoman (188...          NaN
# 143214  {{Infobox French commune\n|image              ...          NaN
#
#        quality_api
# 815           Stub
# 1548          Stub
# 1793          Stub
# 3620          Stub
# 3666          Stub
# ...            ...
# 143002        Stub
# 143028        Stub
# 143030        Stub
# 143120        Stub
# 143214        Stub
#
# [1187 rows x 5 columns]

# %%
Stub2 = Stub.sample(n=650)
Stub2
# Out:
#         page_id                                      title  \
# 106805   198130                                SWEB Energy
# 21275     41274                      Interconnect facility
# 71103    128267    Flat Rock, Surry County, North Carolina
# 127528   258868                               Waikikamukau
# 49475    103267  Yamarrinh Wachangan Islands National Park
# ...         ...                                        ...
# 109037   204468        Trapped in the Body of a White Girl
# 114407   219684                             Appeal to pity
# 123685   246426                            New York Saints
# 115441   222799                              ISO 3166-2:MX
# 125258   251129                                    Ditanyè
#
#                                                      text quality_text  \
# 106805  {{Short description|British electricity suppli...          NaN
# 21275   {{Multiple issues|\n{{More footnotes|date=Janu...          NaN
# 71103   {{Use mdy dates|date=July 2023}}\n{{Infobox se...          NaN
# 127528  {{Short description|Generic name for a small r...          NaN
# 49475   {{Use dmy dates|date=September 2014}}\n{{Use A...          NaN
# ...                                                   ...          ...
# 109037  {{Infobox album|\n| name       = Trapped in th...          NaN
# 114407  {{Short description|Type of logical fallacy}}\...          NaN
# 123685  {{Short description|Former NLL professional bo...          NaN
# 115441  {{Short description|Entry for Mexico in ISO 31...          NaN
# 125258  {{Short description|National anthem of Burkina...          NaN
#
#        quality_api
# 106805        Stub
# 21275         Stub
# 71103         Stub
# 127528        Stub
# 49475         Stub
# ...            ...
# 109037        Stub
# 114407        Stub
# 123685        Stub
# 115441        Stub
# 125258        Stub
#
# [650 rows x 5 columns]

# %%
Stub2.drop(['quality_text'], axis=1, inplace=True)
Stub2.rename(columns={'quality_api': 'quality'}, inplace=True)

# %%
Stub2
# Out:
#         page_id                                      title  \
# 106805   198130                                SWEB Energy
# 21275     41274                      Interconnect facility
# 71103    128267    Flat Rock, Surry County, North Carolina
# 127528   258868                               Waikikamukau
# 49475    103267  Yamarrinh Wachangan Islands National Park
# ...         ...                                        ...
# 109037   204468        Trapped in the Body of a White Girl
# 114407   219684                             Appeal to pity
# 123685   246426                            New York Saints
# 115441   222799                              ISO 3166-2:MX
# 125258   251129                                    Ditanyè
#
#                                                      text quality
# 106805  {{Short description|British electricity suppli...    Stub
# 21275   {{Multiple issues|\n{{More footnotes|date=Janu...    Stub
# 71103   {{Use mdy dates|date=July 2023}}\n{{Infobox se...    Stub
# 127528  {{Short description|Generic name for a small r...    Stub
# 49475   {{Use dmy dates|date=September 2014}}\n{{Use A...    Stub
# ...                                                   ...     ...
# 109037  {{Infobox album|\n| name       = Trapped in th...    Stub
# 114407  {{Short description|Type of logical fallacy}}\...    Stub
# 123685  {{Short description|Former NLL professional bo...    Stub
# 115441  {{Short description|Entry for Mexico in ISO 31...    Stub
# 125258  {{Short description|National anthem of Burkina...    Stub
#
# [650 rows x 4 columns]

# %%
data = pd.concat([FA2, GA2, B2, C2, Start2, Stub2])
data
# Out:
#         page_id                                title  \
# 137096   293253         Princess Alice of Battenberg
# 130870   266376                  Benedetto Pistrucci
# 71006    128158                    Macintosh Classic
# 11275     22790                          Ozzie Smith
# 22502     43455                         Tang dynasty
# ...         ...                                  ...
# 109037   204468  Trapped in the Body of a White Girl
# 114407   219684                       Appeal to pity
# 123685   246426                      New York Saints
# 115441   222799                        ISO 3166-2:MX
# 125258   251129                              Ditanyè
#
#                                                      text quality
# 137096  {{short description|Princess Andrew of Greece ...      FA
# 130870  {{short description|Italian engraver (1783–185...      FA
# 71006   {{Short description|Personal computer by Apple...      FA
# 11275   {{Short description|American professional base...      FA
# 22502   {{pp-protected|small=yes}}\n{{Short descriptio...      FA
# ...                                                   ...     ...
# 109037  {{Infobox album|\n| name       = Trapped in th...    Stub
# 114407  {{Short description|Type of logical fallacy}}\...    Stub
# 123685  {{Short description|Former NLL professional bo...    Stub
# 115441  {{Short description|Entry for Mexico in ISO 31...    Stub
# 125258  {{Short description|National anthem of Burkina...    Stub
#
# [5200 rows x 4 columns]

# %%
data.reset_index(drop=True, inplace=True)

# %%
data.to_csv('/content/drive/MyDrive/학교/Dissertation/Data Collection/dataset.csv')
