# %%
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Drive already mounted at /content/drive; to attempt to forcibly remount, call drive.mount("/content/drive", force_remount=True).

# %%
! pip install wikipedia-api

# %%
! pip install requests

# %%
import requests
import pandas as pd

# %%
def get_wikipedia_article_info(titles):
    # Define the endpoint
    endpoint = "https://en.wikipedia.org/w/api.php"

    # Define parameters
    params = {
        'action': 'query',
        'format': 'json',
        'prop': 'info|pageassessments',
        'titles': '|'.join(titles)
    }

    # Make the request
    response = requests.get(endpoint, params=params)

    # Check if the request was successful
    if response.status_code != 200:
        return f"Error: Unable to fetch data from Wikipedia API. Status code: {response.status_code}"

    # Parse the response
    data = response.json()
    pages = data['query']['pages']

    # Extract relevant information
    article_info = []
    for page_id, page in pages.items():
        title = page.get('title')
        page_id = page.get('pageid')
        quality_class = None
        if 'pageassessments' in page:
            assessments = page['pageassessments']
            if assessments:
                quality_class = next(iter(assessments.values())).get('class')

        article_info.append({
            'title': title,
            'page_id': page_id,
            'quality_class': quality_class
        })

    return article_info

# Example usage
titles = ["AccessibleComputing", "Anarchism", "AfghanistanHistory"]
article_info = get_wikipedia_article_info(titles)
for info in article_info:
    print(info)
# Out:
# {'title': 'AccessibleComputing', 'page_id': 10, 'quality_class': 'Redirect'}
# {'title': 'AfghanistanHistory', 'page_id': 13, 'quality_class': None}
# {'title': 'Anarchism', 'page_id': 12, 'quality_class': 'GA'}

# %%
text = pd.read_csv('/content/drive/MyDrive/학교/Dissertation/Data Collection/text.csv')
text
# Out:
#         Unnamed: 0  page_id                  title  \
# 0                0       10    AccessibleComputing
# 1                1       12              Anarchism
# 2                2       13     AfghanistanHistory
# 3                3       14   AfghanistanGeography
# 4                4       15      AfghanistanPeople
# ...            ...      ...                    ...
# 200529      200529   311318          Reginald Hill
# 200530      200530   311320        1911 revolution
# 200531      200531   311326                 Kangxi
# 200532      200532   311328             Warlordism
# 200533      200533   311329  Wikipedia:Peer Review
#
#                                                      text quality
# 0       #REDIRECT [[Computer accessibility]]\n\n{{rcat...     NaN
# 1       {{short description|Political philosophy and m...      GA
# 2       #REDIRECT [[History of Afghanistan]]\n\n{{Redi...     NaN
# 3       #REDIRECT [[Geography of Afghanistan]]\n\n{{Re...     NaN
# ...

# %%
text.drop(['Unnamed: 0'], axis=1, inplace=True)

# %%
text['title'] = text['title'].astype(str)

# %% [markdown]
# 200534
# - 0-1000

# %%
quality1 = []
for i in range(0, 20000, 50):
    lst = text['title'].iloc[i:i+50].tolist()
    df = get_wikipedia_article_info(lst)
    quality1.append(df)

# %%
len(quality1)
# Out:
# 400

# %%
quality2 = []
for i in range(20000, 40000, 50):
    lst = text['title'].iloc[i:i+50].tolist()
    df = get_wikipedia_article_info(lst)
    quality2.append(df)

# %%
len(quality2)
# Out:
# 400

# %%
quality3 = []
for i in range(40000, 60000, 50):
    lst = text['title'].iloc[i:i+50].tolist()
    df = get_wikipedia_article_info(lst)
    quality3.append(df)

# %%
len(quality3)
# Out:
# 400

# %%
quality4 = []
for i in range(60000, 80000, 50):
    lst = text['title'].iloc[i:i+50].tolist()
    df = get_wikipedia_article_info(lst)
    quality4.append(df)

# %%
len(quality4)
# Out:
# 400

# %%
quality5 = []
for i in range(80000, 100000, 50):
    lst = text['title'].iloc[i:i+50].tolist()
    df = get_wikipedia_article_info(lst)
    quality5.append(df)

# %%
len(quality5)
# Out:
# 400

# %%
quality6 = []
for i in range(100000, 120000, 50):
    lst = text['title'].iloc[i:i+50].tolist()
    df = get_wikipedia_article_info(lst)
    quality6.append(df)

# %%
len(quality6)
# Out:
# 400

# %%
quality7 = []
for i in range(120000, 140000, 50):
    lst = text['title'].iloc[i:i+50].tolist()
    df = get_wikipedia_article_info(lst)
    quality7.append(df)

# %%
len(quality7)
# Out:
# 400

# %%
quality8 = []
for i in range(140000, 160000, 50):
    lst = text['title'].iloc[i:i+50].tolist()
    df = get_wikipedia_article_info(lst)
    quality8.append(df)

# %%
len(quality8)
# Out:
# 400

# %%
quality9 = []
for i in range(160000, 180000, 50):
    lst = text['title'].iloc[i:i+50].tolist()
    df = get_wikipedia_article_info(lst)
    quality9.append(df)

# %%
len(quality9)
# Out:
# 400

# %%
quality10 = []
for i in range(180000, 200000, 50):
    lst = text['title'].iloc[i:i+50].tolist()
    df = get_wikipedia_article_info(lst)
    quality10.append(df)

# %%
len(quality10)
# Out:
# 400

# %%
quality11 = []
for i in range(200000, 200534, 50):
    lst = text['title'].iloc[i:i+50].tolist()
    df = get_wikipedia_article_info(lst)
    quality11.append(df)

# %%
len(quality11)
# Out:
# 11

# %%
quality = []
lst = [quality1, quality2, quality3, quality4, quality5, quality6, quality7, quality8, quality9, quality10]
for i in lst:
    for j in range(400):
        quality.append(i[j])

# %%
len(quality)
# Out:
# 4000

# %%
for i in range(11):
    quality.append(quality11[i])

# %%
len(quality)
# Out:
# 4011

# %%
df_quality = pd.DataFrame(quality[0])
for i in range(1, len(quality)):
    df = pd.DataFrame(quality[i])
    df_quality = pd.concat([df_quality, df])

# %%
len(df_quality)
# Out:
# 200534

# %%
df_quality
# Out:
#                     title   page_id quality_class
# 0                  AbacuS      46.0          None
# 1                 AbalonE      47.0          None
# 2                   AbbeY      51.0          None
# 3                  AbbesS      49.0          None
# 4         AbbevilleFrance      50.0          None
# ..                    ...       ...           ...
# 29           Walter Pater  311303.0          None
# 30           Wang Theatre  311312.0          None
# 31             Warlordism  311328.0          None
# 32                 Zhi-yi  311310.0          None
# 33  Wikipedia:Peer Review  311329.0          None
#
# [200534 rows x 3 columns]

# %%
df_quality.isnull().sum()
# Out:
# title                 0
# page_id               1
# quality_class    181714
# dtype: int64

# %%
df_quality['page_id'].fillna(0, inplace=True)

# %%
df_quality.isnull().sum()
# Out:
# title                 0
# page_id               0
# quality_class    181714
# dtype: int64

# %%
df_quality['page_id'] = df_quality['page_id'].astype(int)

# %%
df_quality['quality_class'].value_counts()
# Out:
# quality_class
# Start       8607
# C           3640
# B           1859
# Stub        1188
#              888
# List         696
# Redirect     613
# Disambig     606
# GA           364
# FA           152
# NA            86
# File          40
# SIA           31
# FL            17
# Project       11
# A              7
# start          6
# Portal         3
# CL             3
# BL             2
# Draft          1
# Name: count, dtype: int64

# %%
df_quality.reset_index(drop=True, inplace=True)
df_quality
# Out:
#                         title  page_id quality_class
# 0                      AbacuS       46          None
# 1                     AbalonE       47          None
# 2                       AbbeY       51          None
# 3                      AbbesS       49          None
# 4             AbbevilleFrance       50          None
# ...                       ...      ...           ...
# 200529           Walter Pater   311303          None
# 200530           Wang Theatre   311312          None
# 200531             Warlordism   311328          None
# 200532                 Zhi-yi   311310          None
# 200533  Wikipedia:Peer Review   311329          None
#
# [200534 rows x 3 columns]

# %%
text.rename(columns={'page_id': 'page_id_text', 'quality': 'quality_text'}, inplace=True)

# %%
df_quality.rename(columns={'page_id': 'page_id_api', 'quality_class': 'quality_api'}, inplace=True)

# %%
text
# Out:
#         page_id_text                  title  \
# 0                 10    AccessibleComputing
# 1                 12              Anarchism
# 2                 13     AfghanistanHistory
# 3                 14   AfghanistanGeography
# 4                 15      AfghanistanPeople
# ...              ...                    ...
# 200529        311318          Reginald Hill
# 200530        311320        1911 revolution
# 200531        311326                 Kangxi
# 200532        311328             Warlordism
# 200533        311329  Wikipedia:Peer Review
#
#                                                      text quality_text
# 0       #REDIRECT [[Computer accessibility]]\n\n{{rcat...          NaN
# 1       {{short description|Political philosophy and m...           GA
# 2       #REDIRECT [[History of Afghanistan]]\n\n{{Redi...          NaN
# 3       #REDIRECT [[Geography of Afghanistan]]\n\n{{Re...          NaN
# 4       #REDIRECT [[Demographics of Afghanistan]]\n\n{...          NaN
# ...

# %%
df_quality
# Out:
#                         title  page_id_api quality_api
# 0                      AbacuS           46        None
# 1                     AbalonE           47        None
# 2                       AbbeY           51        None
# 3                      AbbesS           49        None
# 4             AbbevilleFrance           50        None
# ...                       ...          ...         ...
# 200529           Walter Pater       311303        None
# 200530           Wang Theatre       311312        None
# 200531             Warlordism       311328        None
# 200532                 Zhi-yi       311310        None
# 200533  Wikipedia:Peer Review       311329        None
#
# [200534 rows x 3 columns]

# %%
df_quality.to_csv('/content/drive/MyDrive/학교/Dissertation/Data Collection/quality_api.csv')

# %%
text.to_csv('/content/drive/MyDrive/학교/Dissertation/Data Collection/text.csv')

# %%
combined = text.merge(df_quality, on='title')

# %%
combined
# Out:
#         page_id_text                  title  \
# 0                 10    AccessibleComputing
# 1                 12              Anarchism
# 2                 13     AfghanistanHistory
# 3                 14   AfghanistanGeography
# 4                 15      AfghanistanPeople
# ...              ...                    ...
# 200527        311318          Reginald Hill
# 200528        311320        1911 revolution
# 200529        311326                 Kangxi
# 200530        311328             Warlordism
# 200531        311329  Wikipedia:Peer Review
#
#                                                      text quality_text  \
# 0       #REDIRECT [[Computer accessibility]]\n\n{{rcat...          NaN
# 1       {{short description|Political philosophy and m...           GA
# 2       #REDIRECT [[History of Afghanistan]]\n\n{{Redi...          NaN
# 3       #REDIRECT [[Geography of Afghanistan]]\n\n{{Re...          NaN
# 4       #REDIRECT [[Demographics of Afghanistan]]\n\n{...          NaN
# ...

# %%
id1 = combined['page_id_text'].tolist()
len(id1)
# Out:
# 200532

# %%
id2 = text['page_id_text'].tolist()
len(id2)
# Out:
# 200534

# %%
difference = set(id2)-set(id1)
difference
# Out:
# {49244, 81447}

# %%
missing = text[(text['page_id_text']==49244) | (text['page_id_text']==81447)]
missing
# Out:
#        page_id_text title                                               text  \
# 32604         49244   NaN  {{Short description|Value for unrepresentable ...
# 53627         81447   NaN  #REDIRECT [[Null]]\n\n{{Redirect category shel...
#
#       quality_text
# 32604          NaN
# 53627          NaN

# %%
combined
# Out:
#         page_id_text                  title  \
# 0                 10    AccessibleComputing
# 1                 12              Anarchism
# 2                 13     AfghanistanHistory
# 3                 14   AfghanistanGeography
# 4                 15      AfghanistanPeople
# ...              ...                    ...
# 200527        311318          Reginald Hill
# 200528        311320        1911 revolution
# 200529        311326                 Kangxi
# 200530        311328             Warlordism
# 200531        311329  Wikipedia:Peer Review
#
#                                                      text quality_text  \
# 0       #REDIRECT [[Computer accessibility]]\n\n{{rcat...          NaN
# 1       {{short description|Political philosophy and m...           GA
# 2       #REDIRECT [[History of Afghanistan]]\n\n{{Redi...          NaN
# 3       #REDIRECT [[Geography of Afghanistan]]\n\n{{Re...          NaN
# 4       #REDIRECT [[Demographics of Afghanistan]]\n\n{...          NaN
# ...

# %%
combined2 = pd.concat([combined, missing], ignore_index=True, sort=False)
combined2
# Out:
#         page_id_text                  title  \
# 0                 10    AccessibleComputing
# 1                 12              Anarchism
# 2                 13     AfghanistanHistory
# 3                 14   AfghanistanGeography
# 4                 15      AfghanistanPeople
# ...              ...                    ...
# 200529        311326                 Kangxi
# 200530        311328             Warlordism
# 200531        311329  Wikipedia:Peer Review
# 200532         49244                    NaN
# 200533         81447                    NaN
#
#                                                      text quality_text  \
# 0       #REDIRECT [[Computer accessibility]]\n\n{{rcat...          NaN
# 1       {{short description|Political philosophy and m...           GA
# 2       #REDIRECT [[History of Afghanistan]]\n\n{{Redi...          NaN
# 3       #REDIRECT [[Geography of Afghanistan]]\n\n{{Re...          NaN
# 4       #REDIRECT [[Demographics of Afghanistan]]\n\n{...          NaN
# ...

# %%
combined2.to_csv('/content/drive/MyDrive/학교/Dissertation/Data Collection/combined.csv')
