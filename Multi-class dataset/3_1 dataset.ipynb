# %% [markdown]
# - dataset2.csv

# %%
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Mounted at /content/drive

# %%
import pandas as pd

# %%
reliable = pd.read_csv('/content/drive/MyDrive/학교/Dissertation/Data Collection2/reliable.csv')
reliable.drop(['Unnamed: 0'], axis=1, inplace=True)
reliable
# Out:
#                            title  page_id quality
# 0                      Anarchism       12      GA
# 1                Abraham Lincoln      307      GA
# 2                      Aristotle      308      GA
# 3                       Ayn Rand      339      GA
# 4                      Amphibian      621      FA
# ...                          ...      ...     ...
# 4447                  Starflight   310917      GA
# 4448             Margaret Fuller   311144      FA
# 4449  St Pancras railway station   311178      GA
# 4450                  Water rail   311236      FA
# 4451                   Fin whale   230361      GA
#
# [4452 rows x 3 columns]

# %%
non_reliable = pd.read_csv('/content/drive/MyDrive/학교/Dissertation/Data Collection2/non_reliable.csv')
non_reliable.drop(['Unnamed: 0'], axis=1, inplace=True)
non_reliable
# Out:
#                                          title  page_id quality
# 0                                       Albedo       39       B
# 1                                        Argon      896       B
# 2                                     Avicenna     1130       B
# 3             Alexander Mackenzie (politician)     1235       B
# 4      Americans with Disabilities Act of 1990     1338       B
# ...                                        ...      ...     ...
# 11542                           Homework First   310103    Stub
# 11543                         Wilhelm Xylander   310253    Stub
# 11544                                 Drive-in   310612    Stub
# 11545                      Winkworth Arboretum   311111    Stub
# 11546                        Legion (software)   311255    Stub
#
# [11547 rows x 3 columns]

# %%
reliable['quality'].value_counts()
# Out:
# quality
# GA    3135
# FA    1317
# Name: count, dtype: int64

# %%
non_reliable['quality'].value_counts()
# Out:
# quality
# Start    6997
# C        2480
# B        1248
# Stub      822
# Name: count, dtype: int64

# %% [markdown]
# 1. FA

# %%
FA = reliable[reliable['quality']=='FA']
FA
# Out:
#                       title  page_id quality
# 4                 Amphibian      621      FA
# 6                 Apollo 11      662      FA
# 7                  Apollo 8      663      FA
# 15    Aries (constellation)      798      FA
# 18            Ancient Egypt      874      FA
# ...                     ...      ...     ...
# 4434       Irakli Tsereteli   309142      FA
# 4437        Remain in Light   309803      FA
# 4440       Harmon Killebrew   310171      FA
# 4448        Margaret Fuller   311144      FA
# 4450             Water rail   311236      FA
#
# [1317 rows x 3 columns]

# %%
FA2 = FA.sample(n=1200, random_state=1)
FA2
# Out:
#                                          title  page_id quality
# 3129                           Mayan languages   182013      FA
# 3501                                Mu'awiya I   207068      FA
# 3111                          The Fountainhead   180464      FA
# 3640                          Northern pintail   218361      FA
# 616                          Manhattan Project    19603      FA
# ...                                        ...      ...     ...
# 505                            James G. Blaine    16208      FA
# 3678                               Las Meninas   222127      FA
# 4102  Niandra LaDes and Usually Just a T-Shirt   266477      FA
# 1696                          Epacris impressa    61363      FA
# 1785                         Jacques Offenbach    65414      FA
#
# [1200 rows x 3 columns]

# %% [markdown]
# 2. GA

# %%
GA = reliable[reliable['quality']=='GA']
GA
# Out:
#                            title  page_id quality
# 0                      Anarchism       12      GA
# 1                Abraham Lincoln      307      GA
# 2                      Aristotle      308      GA
# 3                       Ayn Rand      339      GA
# 5                    Agriculture      627      GA
# ...                          ...      ...     ...
# 4445                       Croup   310898      GA
# 4446                    Bat'leth   310912      GA
# 4447                  Starflight   310917      GA
# 4449  St Pancras railway station   311178      GA
# 4451                   Fin whale   230361      GA
#
# [3135 rows x 3 columns]

# %%
GA2 = GA.sample(n=1200, random_state=1)
GA2
# Out:
#                           title  page_id quality
# 2125                  Bobby Orr    86913      GA
# 3231        USS Florida (BB-30)   189820      GA
# 4086       New Jersey Route 147   264706      GA
# 4051              Roger Federer   262376      GA
# 2426  Rosendale (CDP), New York   127480      GA
# ...                         ...      ...     ...
# 4121                  GoldenEye   268833      GA
# 3161                Ted Kennedy   184136      GA
# 3023                 Hugh Grant   170779      GA
# 2246   Harrison County, Indiana    96117      GA
# 14       Asteroids (video game)      785      GA
#
# [1200 rows x 3 columns]

# %% [markdown]
# 3. B-class

# %%
B = non_reliable[non_reliable['quality']=='B']
B
# Out:
#                                         title  page_id quality
# 0                                      Albedo       39       B
# 1                                       Argon      896       B
# 2                                    Avicenna     1130       B
# 3            Alexander Mackenzie (politician)     1235       B
# 4     Americans with Disabilities Act of 1990     1338       B
# ...                                       ...      ...     ...
# 1243                      Antoninus Liberalis   310260       B
# 1244                         Pictish language   310437       B
# 1245                                 Achewood   310619       B
# 1246                        Fitness landscape   310599       B
# 1247                North Pacific right whale   311104       B
#
# [1248 rows x 3 columns]

# %%
B2 = B.sample(n=1200, random_state=1)
B2
# Out:
#                       title  page_id quality
# 860   Numerical integration   170089       B
# 710        Antelope, Oregon   130986       B
# 799           Sopwith Camel   152993       B
# 432    Anne of Green Gables    58406       B
# 236           Scotch whisky    28896       B
# ...                     ...      ...     ...
# 1150        Bernard Tschumi   267886       B
# 999                   Gudea   208722       B
# 1046         Jill Clayburgh   225561       B
# 25          Binary relation     3931       B
# 196           Phase (waves)    24047       B
#
# [1200 rows x 3 columns]

# %% [markdown]
# 4. C-class

# %%
C = non_reliable[non_reliable['quality']=='C']
C
# Out:
#                                       title  page_id quality
# 1248  American National Standards Institute      659       C
# 1249                              Mouthwash      782       C
# 1250                            Agnosticism      894       C
# 1251                                  Aaron     1006       C
# 1252                                Apple I     1344       C
# ...                                     ...      ...     ...
# 3723                    Modern Jazz Quartet   310911       C
# 3724                        Victor Vasarely   311107       C
# 3725          American Humanist Association   311264       C
# 3726                  Binge eating disorder   311254       C
# 3727                           Hideaki Anno   311256       C
#
# [2480 rows x 3 columns]

# %%
C2 = C.sample(n=1200, random_state=1)
C2
# Out:
#                                                  title  page_id quality
# 3202                                Strategy & Tactics   222467       C
# 2282                                      Biomechanics   105355       C
# 2556                                 Bon Air, Virginia   137544       C
# 2603                                 Zaphod Beeblebrox   143994       C
# 2759                     Cabinet of the United Kingdom   162790       C
# ...                                                ...      ...     ...
# 2957  Stratford-upon-Avon and Midland Junction Railway   187957       C
# 2801                         Royal Shakespeare Company   167785       C
# 2921                                   Kronecker delta   182890       C
# 2414                  Saginaw Township North, Michigan   119002       C
# 1877                                         Cockfight    54920       C
#
# [1200 rows x 3 columns]

# %% [markdown]
# 5. Start-class

# %%
Start = non_reliable[non_reliable['quality']=='Start']
Start
# Out:
#                                 title  page_id quality
# 3728                       Anthophyta      779   Start
# 3729               Alfons Maria Jakob      892   Start
# 3730                  Acoustic theory     1234   Start
# 3731      Ashmore and Cartier Islands     1227   Start
# 3732   Telecommunications in Anguilla     1223   Start
# ...                               ...      ...     ...
# 10720                      V20 engine   310614   Start
# 10721                Cookie Gilchrist   310743   Start
# 10722                    Blues Magoos   310895   Start
# 10723                         Neustar   311108   Start
# 10724   Thomas Walker (naval officer)   311260   Start
#
# [6997 rows x 3 columns]

# %%
Start2 = Start.sample(n=1200, random_state=1)
Start2
# Out:
#                            title  page_id quality
# 7189     Conetoe, North Carolina   127879   Start
# 8113       West Sharyland, Texas   136125   Start
# 6956   New Boston, New Hampshire   124782   Start
# 6132         Parkville, Maryland   116355   Start
# 4722                  Match play    92729   Start
# ...                          ...      ...     ...
# 6865          Cortland, Nebraska   123923   Start
# 9797                  Goya Foods   232964   Start
# 10306           Operation Granby   269070   Start
# 3987   Lepsius Standard Alphabet    28131   Start
# 7956       Freeman, South Dakota   134888   Start
#
# [1200 rows x 3 columns]

# %% [markdown]
# 6. Stub-class

# %%
Stub = non_reliable[non_reliable['quality']=='Stub']
Stub
# Out:
#                       title  page_id quality
# 10725  Agapanthus africanus     1543    Stub
# 10726       Andrea Andreani     1754    Stub
# 10727          Alfonso Leng     2329    Stub
# 10728       Arthur J. Stone     2729    Stub
# 10729            Agra Canal     3122    Stub
# ...                     ...      ...     ...
# 11542        Homework First   310103    Stub
# 11543      Wilhelm Xylander   310253    Stub
# 11544              Drive-in   310612    Stub
# 11545   Winkworth Arboretum   311111    Stub
# 11546     Legion (software)   311255    Stub
#
# [822 rows x 3 columns]

# %%
Stub2 = Stub.sample(n=800, random_state=1)
Stub2
# Out:
#                                title  page_id quality
# 11253                         Lunner   178056    Stub
# 11056             Bancroft, Kentucky   115175    Stub
# 11460                     Fur Patrol   272046    Stub
# 10742  Goal line (gridiron football)    10664    Stub
# 11113              Flen Municipality   132222    Stub
# ...                              ...      ...     ...
# 11228              Fontaine-l'Évêque   175235    Stub
# 11478           What More Can I Ask?   285291    Stub
# 10940                     Adam Marsh    94756    Stub
# 11305              Babel (newspaper)   198957    Stub
# 11287    Bengt Jönsson (Oxenstierna)   187699    Stub
#
# [800 rows x 3 columns]

# %% [markdown]
# ----------

# %%
data = pd.concat([FA2, GA2, B2, C2, Start2, Stub2])
data.reset_index(drop=True, inplace=True)
data
# Out:
#                             title  page_id quality
# 0                 Mayan languages   182013      FA
# 1                      Mu'awiya I   207068      FA
# 2                The Fountainhead   180464      FA
# 3                Northern pintail   218361      FA
# 4               Manhattan Project    19603      FA
# ...                           ...      ...     ...
# 6795            Fontaine-l'Évêque   175235    Stub
# 6796         What More Can I Ask?   285291    Stub
# 6797                   Adam Marsh    94756    Stub
# 6798            Babel (newspaper)   198957    Stub
# 6799  Bengt Jönsson (Oxenstierna)   187699    Stub
#
# [6800 rows x 3 columns]

# %%
data.to_csv('/content/drive/MyDrive/학교/Dissertation/Multi-class Dataset/dataset2.csv')
